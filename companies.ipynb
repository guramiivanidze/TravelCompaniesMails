# %%
htrml_par = '''<body onload="">

<script type="text/javascript" language="javascript">
  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');

  ga('create', 'UA-8204442-1', 'auto');
  ga('send', 'pageview');
</script>







<div class="container-fluid pt-1 px-2" style="background-color: #ffed00;">
    <div class="container px-0 mt-1" style="max-width:960px; background-color: #ffed00;">

    

<div>
            






<!-- baneris Chasmisas movxsnat

<div style="height:30px;"></div>

-->

<link rel="stylesheet" href="css/style_sidebar.css">
<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/malihu-custom-scrollbar-plugin/3.1.5/jquery.mCustomScrollbar.min.css">
<script defer="" src="https://use.fontawesome.com/releases/v5.0.13/js/solid.js" integrity="sha384-tzzSw1/Vo+0N5UhStP3bvwWPq+uvzCMfrN1fEFe+xBmv1C/AtVX5K0uZtmcHitFZ" crossorigin="anonymous"></script>
<script defer="" src="https://use.fontawesome.com/releases/v5.0.13/js/fontawesome.js" integrity="sha384-6OIrr52G08NpOFSZdxxz1xdNSndlD4vdcf/q2myIUVO0VsqaGHJsB0RaBE01VTOY" crossorigin="anonymous"></script>
<script src="https://cdnjs.cloudflare.com/ajax/libs/malihu-custom-scrollbar-plugin/3.1.5/jquery.mCustomScrollbar.concat.min.js"></script>
<script src="js/script_SR.js"></script>



<div id="Shesvla_Div" class="NotActive" style="width: 5px; height: 5px;">
    <div style="background:#fff;">



<noscript>
<div align="center" style="width:200px; height:100px; line-height:100px; background-color:#0099CC; color:#333333; font-family:Arial; font-weight:bold; font-size:18px;">Noscript</div>
</noscript>

<table border="0" cellpadding="0" cellspacing="0">
<tbody><tr>


<td align="right" valign="middle">

<table border="0" cellspacing="0" cellpadding="0" style="width:100%; height:100%; background-color:rgba(0,0,0,0.5); position:fixed; left:0px; top:0px; z-index:10002;" id="login_table_top">
<tbody><tr>
<td align="center" valign="middle" style="width:100%; height:100px;" id="login_table_">

<!--<div style="background-color:#999999; width:0px; height:0px; position:relative; right:0px; top:28px; z-index:1000;">
<div style="width:265px; height:0px; position:absolute; right:0px; top:0px; z-index:1000;">-->
<table width="265" border="0" cellspacing="10" cellpadding="0" style="border:1px solid #BBBBBB; background-color:#FFFFFF; box-shadow:0px 2px 6px rgba(0,0,0,0.4);" id="login_table_top">
<tbody><tr>
<td width="243" align="center" valign="middle">

<form action="login.php" method="post" style="margin:0px; padding:0px;">
<table width="243" border="0" cellpadding="0" cellspacing="0">

<tbody><tr>
    <td width="243" align="right" valign="middle" id="login_table_"><img src="img/close_2.png" width="12" height="12" alt="" style="margin-top: 10px; cursor:pointer;" onmouseover="this.src='img/close_1.png';" onmouseout="this.src='img/close_2.png';" onclick=" document.getElementById('Shesvla_Div').classList.remove('Active'); document.getElementById('Shesvla_Div').classList.add('NotActive');  document.getElementById('shesvla_').style.backgroundImage='url(img/login_form_display_icon_c.png)';" id="login_table_"></td>
</tr>

<tr>
<td width="243" height="115" align="center" valign="middle" id="login_table_"><img src="img/login_user_icon.png" name="login_table_" width="85" height="85" id="login_table_" style="margin-bottom:10px;"></td>
</tr>

<tr>
<td width="243" align="center" valign="middle" id="login_table_"><div align="left" style="width:223px; height:28px; position:relative; left:0px; top:0px;">
<input name="email" id="login_email" type="text" value="ელ-ფოსტა" style="width:223px; height:26px; position:absolute; left:0px; top:0px; padding:0px 6px 0px 40px; margin:0px; border:1px solid #c7c7c7; color:#666666; font-size: 14px; cursor:text; z-index:10;" onfocus="
this.style.border='1px solid #f0e037';
if(this.value=='ელ-ფოსტა'){this.value='';}
" onblur="
this.style.border='1px solid #c7c7c7';
if(this.value==''){this.value='ელ-ფოსტა';}
">
<img src="img/login_input_email_l.png" width="38" height="28" style="position:absolute; left:0px; top:0px; cursor:default; z-index:11;" id="login_table_">
</div></td>
</tr>
<tr>
<td width="243" height="14" align="left" valign="bottom" style="font-family:myfont_m; font-size:13px; cursor:default;" id="login_table_"><!--პაროლი--></td>
</tr>
<tr>
<td width="243" align="center" valign="middle" id="login_table_">

<div style="width:223px; height:28px; position:relative; left:0px; top:0px;">
<!--<input name="pass" id="login_pass" type="text" value="პაროლი" style="width:175px; height:26px; position:absolute; left:0px; top:0px; padding:0px 6px 0px 40px; margin:0px; border:1px solid #c7c7c7; color:#666666; cursor:text;"

onfocus="
this.style.border='1px solid #f0e037';
if(this.value=='პაროლი'){this.value='';}
"
onblur="
this.style.border='1px solid #c7c7c7';
if(this.value==''){this.value='პაროლი';}
" />-->
<div align="left" style="width:223px; height:28px; position:relative; left:0px; top:0px; margin-top:0px; z-index:10;" id="pass_box">
<table width="223" height="28" border="0" cellpadding="0" cellspacing="0" style="border:1px solid #c7c7c7; background-color:#FFFFFF; position:absolute; left:0px; top:0px; z-index:0;" id="pass_border">
<tbody><tr><td width="221" height="26"></td></tr>
</tbody></table>
<div style="width:175px; height:auto; margin:0px; padding:6px 8px 6px 40px; background:transparent; border:none; outline:none; cursor:text; font-family:sylfaen; font-size:14px; color:#666666; position:absolute; left:0px; top:0px; z-index:1;" align="left" id="pass_def_val">პაროლი</div>
<input style="width:223px; height:28px; margin:0px; padding:6px 8px 6px 40px; background:transparent; border:none; outline:none; cursor:text; font-family:Arial; font-size:14px; position:absolute; left:0px; top:0px; z-index:2;" name="pass" id="login_pass" type="password" value="" onfocus="document.getElementById('pass_def_val').innerHTML='';document.getElementById('pass_border').style.border='1px solid #f0e037';" onblur="if(this.value==''){document.getElementById('pass_def_val').innerHTML='პაროლი';}document.getElementById('pass_border').style.border='1px solid #c7c7c7';">
</div>
<img src="img/login_input_pass_l.png" width="38" height="28" style="position:absolute; left:0px; top:0px; cursor:default; z-index:11;" id="login_table_">
</div>







</td>
</tr>
<tr>
<td width="243" height="20" align="left" valign="bottom" id="login_table_"><a href="forgot_password.php?lan=geo" style="font-family:sylfaen; font-size:11px; text-decoration:none; color:#005e9d; cursor:pointer; margin-left:10px;" id="login_table_">დაგავიწყდათ პაროლი?</a></td>
</tr>
<tr>
<td width="243" height="14" style="line-height:14px;" id="login_table_"></td>
</tr>
<tr>
<td width="243" height="26" align="center" valign="middle" id="login_table_"><table width="223" height="26" border="0" cellpadding="0" cellspacing="0">
<tbody><tr>
<td width="143" height="26" align="left" id="login_table_"><a id="login_table_" style="background:transparent url(img/remember_0.png) left no-repeat; font-family:sylfaen; font-size:11px; color:#333333; cursor:pointer; padding-left:44px; padding-bottom:2px; padding-top:2px; letter-spacing:0px;" onclick="F_remember(this,'save');" onmousedown="return false;">დამიმახსოვრე</a><input name="save" id="save" type="hidden" value="0" style="width:30px;">
<!--<label onmousedown="return false;" id="login_table_"><input name="save" id="login_table_" type="checkbox" value="1" />დამიმახსოვრე</label>--></td>
<td width="80" height="26" align="left" valign="top" bgcolor="#838383"><input name="submit" type="submit" value="შესვლა" style="width:80px; height:26px; padding:0px; margin:0px; border:none; outline:none; cursor:pointer; background-color:#ffe900; font-family:myfont_m_normal; font-size:14px; font-weight: bold; color:black; letter-spacing:0px;line-height: 30px;" id="login_table_"></td>
</tr>
</tbody></table></td>
</tr>
</tbody></table>
</form>


<table width="243" border="0" cellpadding="0" cellspacing="0">
<tbody><tr>
<td width="243" height="14" style="line-height:14px;" id="login_table_"></td>
</tr>
<tr>
<td align="center" valign="top" width="243" height="10" style="line-height:10px;" id="login_table_">

<div style="width:223px; height:1px; border-top:1px solid #e0e0e0;" id="login_table_"></div>

</td>
</tr>
<tr>
<td width="243" height="46" align="center" valign="top" id="login_table_" style="line-height:14px;"><table width="223" border="0" cellspacing="0" cellpadding="0">
<tbody><tr>
<td width="110" height="26" align="left" valign="top" id="login_table_" style="border-right:3px solid #FFFFFF;"><a href="registration_form.php?lan=geo" style="text-decoration:none; margin:0px; padding:0px;">
<div align="center" style="width:110px; height:26px; line-height:29px; cursor:pointer; background-color:#8f7f58; font-family:myfont_m; font-size:13px; color:#ffffff; overflow:hidden;" id="login_table_">რეგისტრაცია</div></a></td>
<td width="113" align="right" valign="top" id="login_table_"><!--if($IsAccess)-->

<a href="https://www.facebook.com/v2.5/dialog/oauth?client_id=352670461544148&amp;state=c1e24b07336866d872e9927f66778316&amp;response_type=code&amp;sdk=php-sdk-5.6.1&amp;redirect_uri=https%3A%2F%2Fwww.yell.ge%2Ffb-callback.php&amp;scope=email" style="text-decoration:none; margin:0px; padding:0px;">
    	<img src="img/login_with_facebook_geo.gif" name="login_table_" width="110" height="26" id="login_table_" style="border:none; cursor:pointer;">
</a>
<!--<a href="login_facebook.php?fn=//companies.php&lan=geo&rub=445" 
	style="text-decoration:none; margin:0px; padding:0px;">
    	<img src="img/login_with_facebook//_geo.gif" name="login_table_" 
        width="110" height="26" id="login_table_" style="border:none; cursor:pointer;" />
</a>-->

</td>
</tr>
</tbody></table></td>
</tr>
<tr>
<td width="243" height="0" style="line-height:0px;" id="login_table_"></td>
</tr>
</tbody></table>


</td>
</tr>
</tbody></table>
<!--</div>
</div>-->

</td>
</tr>
</tbody></table>






</td>












</tr>
</tbody></table>



</div></div>

<div>
        <!-- Sidebar Content -->
        <nav id="sidebar" class="mCustomScrollbar _mCS_1 mCS-autoHide mCS_no_scrollbar" style="overflow: visible;"><div id="mCSB_1" class="mCustomScrollBox mCS-minimal mCSB_vertical mCSB_outside" style="max-height: none;" tabindex="0"><div id="mCSB_1_container" class="mCSB_container mCS_y_hidden mCS_no_scrollbar_y" style="position:relative; top:0; left:0;" dir="ltr">
            <div id="dismiss">
                <svg class="svg-inline--fa fa-times fa-w-11" style="color: #787878;" aria-hidden="true" data-prefix="fa" data-icon="times" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 352 512" data-fa-i2svg=""><path fill="currentColor" d="M242.72 256l100.07-100.07c12.28-12.28 12.28-32.19 0-44.48l-22.24-22.24c-12.28-12.28-32.19-12.28-44.48 0L176 189.28 75.93 89.21c-12.28-12.28-32.19-12.28-44.48 0L9.21 111.45c-12.28 12.28-12.28 32.19 0 44.48L109.28 256 9.21 356.07c-12.28 12.28-12.28 32.19 0 44.48l22.24 22.24c12.28 12.28 32.2 12.28 44.48 0L176 322.72l100.07 100.07c12.28 12.28 32.2 12.28 44.48 0l22.24-22.24c12.28-12.28 12.28-32.19 0-44.48L242.72 256z"></path></svg><!-- <i class="fa fa-times" style="color: #787878;"></i> -->
            </div>

            <ul style="list-style-type: none; padding-left: 10px!important;">
                <li>
                    <div class="lan_menu">
                        <a href="https://www.yell.ge/companies.php?lan=geo&amp;rub=445" class="lang-active">GEO </a>
                    </div>
                    <div class="lan_menu">
                        <a href="https://www.yell.ge/companies.php?lan=eng&amp;rub=445" class="lang">ENG </a>
                    </div>
                    <div class="lan_menu">
                        <a href="https://www.yell.ge/companies.php?lan=rus&amp;rub=445" class="lang">RUS </a>
                    </div>
                </li>
            </ul>
            
            <ul class="pt-0 list-unstyled components">
                                <li>
                    <a class="top_menu_link" id="shesvla_top" onclick="F_shesvla_click();return false;" onmousedown="return false;" style="font-family:sylfaen;">შესვლა</a>
                </li>
                                
                <li>
                    <a class="top_menu_link" href="http://yell.ge/registration_form.php?lan=geo" style="font-family:sylfaen;">რეგისტრაცია</a>
                </li>
                <div class="profile_separator"></div>
                <li>
                    <a class="top_menu_link" href="http://yell.ge/ada/onlo.php" target="_blank" style="font-family:sylfaen;">რეკლამა</a>
                </li>
                
                <li>
                    <a class="top_menu_link" href="https://www.yell.ge/add_company.php?lan=geo" style="font-family:sylfaen;">დაამატეთ კომპანია</a>
                </li>
                
                <li>
                    <a class="top_menu_link" href="http://yell.ge/about_us.php?lan=geo" style="font-family:sylfaen;">ჩვენ შესახებ</a>
                </li>
                
                <li>
                    <a class="top_menu_link" href="http://yell.ge/contact.php?lan=geo" style="font-family:sylfaen;">კონტაქტი</a>
                </li>
                
                <div class="profile_separator"></div>
                
                <li>
                    <a class="top_menu_link" href="http://www.yell.ge/info/" target="_blank" style="font-family:sylfaen; background:url(img/info_banner_icon_15x15.png) left no-repeat; padding-left:19px;">ინფო გვერდები</a>
                </li>             
                
                
                
            </ul>
           
        </div></div><div id="mCSB_1_scrollbar_vertical" class="mCSB_scrollTools mCSB_1_scrollbar mCS-minimal mCSB_scrollTools_vertical" style="display: none;"><div class="mCSB_draggerContainer"><div id="mCSB_1_dragger_vertical" class="mCSB_dragger" style="position: absolute; min-height: 50px; height: 0px; top: 0px;"><div class="mCSB_dragger_bar" style="line-height: 50px;"></div></div><div class="mCSB_draggerRail"></div></div></div></nav>

        <!-- Top Menu Content  -->
        <div id="content" style="max-width: 960px;">

            <nav class="navbar navbar-expand-md navbar-light pr-0">
                <div>
                    <a class="navbar-brand" href="index.php"><img src="img/map/logo.png" width="190" height="71" alt="" style="cursor:pointer;"></a>
                </div>
                <button class="navbar-toggler" type="button" id="sidebarCollapse" data-toggle="collapse" style="border: none;">
                    <svg class="svg-inline--fa fa-bars fa-w-14" aria-hidden="true" data-prefix="fa" data-icon="bars" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 448 512" data-fa-i2svg=""><path fill="currentColor" d="M16 132h416c8.837 0 16-7.163 16-16V76c0-8.837-7.163-16-16-16H16C7.163 60 0 67.163 0 76v40c0 8.837 7.163 16 16 16zm0 160h416c8.837 0 16-7.163 16-16v-40c0-8.837-7.163-16-16-16H16c-8.837 0-16 7.163-16 16v40c0 8.837 7.163 16 16 16zm0 160h416c8.837 0 16-7.163 16-16v-40c0-8.837-7.163-16-16-16H16c-8.837 0-16 7.163-16 16v40c0 8.837 7.163 16 16 16z"></path></svg><!-- <span class="fa fa-bars"></span> -->
                </button>
                    
        <div class="collapse navbar-collapse" id="collapsibleNavbar">
            <ul class="navbar-nav ml-auto">
                <li class="nav-item pr-2" style="text-align: right">
                    <a href="http://yell.ge/ada/onlo.php" target="_blank" style="padding:4px 0px 0px 22px; background:transparent url(img/adsmo.png) left no-repeat; font-family:myfont_m; font-size:12px; font-weight:normal; color:#000000; cursor:pointer; white-space:nowrap;">რეკლამა</a>
                </li>
                 <li class="nav-item pl-5 pr-2" style="text-align: right">
                    <a href="https://www.yell.ge/add_company.php?lan=geo" style="padding:4px 0px 0px 22px; background:transparent url(img/addco.png) left no-repeat; font-family:myfont_m; font-size:12px; font-weight:normal; color:#000000; cursor:pointer; white-space:nowrap;">დაამატეთ კომპანია</a>
                </li>
    
      
                <li class="nav-item pl-5 pr-2" style="text-align: right">
                    <div>
                    <span><a href="https://www.yell.ge/companies.php?lan=geo&amp;rub=445" style="font-size:10px; font-weight:bold; font-family:Arial; color:#231f20;">GEO </a> 
      
                    <img src="img/lan_sep.gif" width="1" height="16" style="margin: 4px 0px 0px 6px;"> </span>
       
                    <span><a href="https://www.yell.ge/companies.php?lan=eng&amp;rub=445" style="font-size:10px; font-weight:bold; font-family:Arial; color:#231f20;">ENG</a> 
      
                    <img src="img/lan_sep.gif" width="1" height="16" style="margin: 4px 0px 0px 6px;"> </span>
      
                    <span> <a href="https://www.yell.ge/companies.php?lan=rus&amp;rub=445" style="font-size:10px; font-weight:bold; font-family:Arial; color:#231f20;">RUS</a> </span>
      
                    </div>
                </li> 
      
            </ul>
        </div>  
                   
                
            </nav>

                    
            
        </div>
    </div>
<div class="overlay"></div>

<script type="text/javascript">
        $(document).ready(function () {
            $("#sidebar").mCustomScrollbar({
                theme: "minimal"
            });

            $('#dismiss, .overlay').on('click', function () {
                $('#sidebar').removeClass('active');
                $('.overlay').removeClass('active');
            });

            $('#sidebarCollapse').on('click', function () {
                $('#sidebar').addClass('active');
                $('.overlay').addClass('active');
                $('.collapse.in').toggleClass('in');
                $('a[aria-expanded=true]').attr('aria-expanded', 'false');
            });
        });
    </script></div>

    </div>
</div>


    

<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">


<div class="container-fluid pb-3" style="background-color: #ffed00; padding: 5px;">

    <div class="container py-1 px-0" style="max-width:960px;">
        
        <div class="row mb-3" style="max-width: 340px;">        
                <style>
       .search_img{width: 15px; height: 15px;cursor: pointer;}
       .search_action{font-size: 13px;color: #222222;text-decoration: none;outline: none;}
       .search_action span{position: relative;top:2px;left: 2px;cursor: pointer;}
       .search_action.geo{font-family: myfont_m;}
       .search_action.eng, .search_action.rus{font-family:Arial}
       .search_active{
           background-color: #ffe500;
           border: 0px solid #c9b602;
           border-radius: 5px;
           top: -5px;
           position: relative;
           width: max-content;
           padding: 5px 10px 5px 5px;
           box-shadow: inset 2px 2px 0px 0px rgba(0,0,0,0.1);
       }
    </style>
    <script>
        var get_lan = "geo";
        var s_b = 1;
        $(document).ready(function() {
        switch(get_lan){
            case "geo": 
                misamarti_get_lan = "ქუჩა"; 
                ubani_get_lan = 'უბანი';
                all_get_lan = 'ყველა';
                break;
            case "eng": 
                misamarti_get_lan = "ADDRESS"; 
                ubani_get_lan = 'DISTRICT';
                all_get_lan = 'ALL';
                break;
            case "rus": 
                misamarti_get_lan = "АДРЕС"; 
                ubani_get_lan = 'РАЙОН';
                all_get_lan = 'ВСЁ';
                break;
        }
        $('.search_div').removeClass('search_active');
        if(s_b==2){
            $('.search_div.by_tel').addClass('search_active');
        }else{
            $('.search_div.by_word').addClass('search_active');
        }
    })
    </script>
    <div class="col-4">
        <div class="search_div by_word search_active">
            <a href="https://www.yell.ge/index.php" class="search_action  geo">
                <img src="/img/search_company.png" class="search_img"> 
                <span>სახელით</span>
            </a>
        </div>
    </div>
    <div class="col-4 p-0">
        <div class="search_div by_tel">
            <a href="https://www.yell.ge/index.php?lan=geo&amp;s_b=2" class="search_action  geo">
                <img src="/img/search_tel.png" class="search_img"> 
                <span>ტელეფონით</span>
            </a>
        </div>
    </div>
    <div class="col-4 p-0">
        <div class="search_div by_add">
            <a href="https://www.yell.ge/search_map.php?lan=geo&amp;S_lan=geo&amp;s_b=3&amp;SI_1=თბილისი" class="search_action geo">
                <img src="/img/search_address.png" style="width: 12px;"> 
                <span>მისამართით</span>
            </a>
        </div>
    </div>
    

 </div>
            
<!--            <div class="col-md-4"> </div>-->
    </div>







    
    
    
    


<div class="container pb-2 px-0" style="max-width:960px;">
    
<div class="row pr-0 mr-0">


<div style="width:100%; height:0px; display:none; position:relative; left:0px; top:0px;" id="error_0">
<div style="width:100%; height:auto; position:absolute; left:0px; bottom:0px; font-family:Sylfaen; font-size:12px; color:#CC0000;" align="left" id="error_2_inner">

საძიებო სიტყვა უნდა შედგებოდეს მინიმუმ ორი სიმბოლოსგან.
</div>
</div>
    <style>
        @media screen and (max-width: 450px) {
   .margin_search{
      margin-left: 2px!important;
   }
   
   
}


@media screen and (max-width: 335px) {
   .company_search_td{
      width: 295px;
      
   }
   
   .city_search_td{
      width: 160px;
      
   }
   .search_margin_left{
      margin-left: 22px;
   }  
   
   }
   
@media screen and (min-width: 336px) and (max-width: 354px) {
   .company_search_td{
      width: 300px;
      
   }
   .city_search_td{
      width: 160px;
      
   }
   
   .search_margin_left{
      margin-left: 27px;
   }  
   }
   
   @media screen and (min-width: 355px) and (max-width: 360px) {
   .company_search_td{
      width: 325px;
      
   }
   
   .city_search_td{
      width: 185px;
      
   }
   
   
   .search_margin_left{
      margin-left: 27px;
   }  
   }
   
   
 @media screen and (min-width: 361px) and (max-width: 375px) {
   .company_search_td{
      min-width: 345px;
   }  
   
   .city_search_td{
      width: 200px;
      
   }
   
   .search_margin_left{
      margin-left: 32px;
   }  
   
   
}

@media screen and (min-width: 376px) and (max-width: 409px) {
   .company_search_td{
      min-width: 355px;
   }  
   
   .city_search_td{
      width: 210px;
      
   }
   
   .search_margin_left{
      margin-left: 32px;
   }  
   
   
}


@media screen and (min-width: 410px) and (max-width: 767px) {
   .company_search_td{
      min-width: 375px;
   } 
   
   .city_search_td{
      width: 213px;
      
   }
   
   .search_margin_left{
      margin-left: 49px;
   }  
}




@media screen and (min-width: 768px) and (max-width: 875px) {
   .company_search_td{
      min-width: 347px;
   }  
   
   .city_search_td{
      width: 180px;
      
   }
   
   .search_margin_left{
      margin-left: 28px;
   }  
}


@media screen and (min-width: 876px)  {
   .company_search_td{
      min-width: 347px;
   }  
   
   .city_search_td{
      width: 213px;
      
   }
   
   .search_margin_left{
      margin-left: 28px;
   }  
}





  
   
      
        </style>
<div class="col-md-7 pb-2 pr-0 margin_search">
<table height="42" border="0" cellpadding="0" cellspacing="0" bgcolor="#FFFFFF" id="SI_0_table">
<tbody><tr>

<td height="42" align="center" valign="middle" style="height: 42px;" class="company_search_td">


<form action="" method="post" id="FORM_0" name="FORM_0">
<input type="text" name="SI_0" autocapitalize="off" value="ტურისტული კომპანიები" onfocus="search_start(0,this,'კომპანიის სახელი ან საქმიანობა',this.value,'geo')" onblur="search_end(0,this,'კომპანიის სახელი ან საქმიანობა',this.value,'geo')" onkeydown="search_pre_select(event,0)" class="company_search_td" style="height:40px; margin:0px; padding:2px 4px 0px 10px; border:0px; background-color:transparent;
     
outline:0px; cursor:text; font-size:14px; 
font-weight:500; font-family:myfont_m; 
color:#333333;
" id="SI_0" autocomplete="off">
</form>

</td>

<td class="d-none d-lg-block" width="145" height="42" align="left" valign="middle" bgcolor="#eaeaea" style="background-position:left; background-repeat:repeat-x; font-family:myfont_m; font-size:11px; " id="chbox_o_b_n_table"><label style="cursor:pointer; margin:14px 0 0 10px;"><input name="" type="checkbox" value="" onchange="F_only_bussiness_name(this.checked)" style="outline:0px; cursor:pointer; line-height:42px;" id="o_b_n_chbx"> კომპანიის სახელით</label></td>


</tr>
<tr>
<td height="0" colspan="3" align="left" valign="top">
<div style="max-width:355px; height:0px; position:relative; left:0px; top:0px;" id="SI_0_pre_inner"></div>
</td>
</tr>
</tbody></table>

    
    
<div style="width:100%; height:0px; display:none; position:relative; left:0px; top:20px; background-color:#ffe600;" id="error_2">
<div style="width:100%; height:auto; position:absolute; left:0px; bottom:0px; font-family:Sylfaen; font-size:12px; color:#CC0000;" align="left">მისამართი უნდა იყოს მინიმუმ 2 სიმბოლო.</div>
</div>
        <div class="row mr-0 pr-0">
<div class="col">
<table width="355" height="32" border="0" cellpadding="0" cellspacing="0" bgcolor="#FFFFFF" id="SI_2_table" style="margin-top:20px; display:none;">
<tbody><tr>

<td width="347" height="42" align="center" valign="middle">

<form action="" method="post" id="FORM_2" name="FORM_2">
<input type="text" name="SI_2" value="ქუჩა" onfocus="search_start(2,this,'ქუჩა',this.value,'geo')" onblur="search_end(2,this,'ქუჩა',this.value,'geo')" onkeydown="search_pre_select(event,2)" style="width:339px; height:40px; margin:0px; padding:0px 4px 0px 4px; border:0px; background-color:transparent; outline:0px; cursor:text; font-size:12px; font-weight:500; font-family:myfont_m; color:#AAAAAA;" id="SI_2" autocomplete="off">
</form>
</td>

</tr>
<tr>
<td height="0" colspan="3" align="left" valign="top">
<div style="width:355px; height:0px; position:relative; left:0px; top:0px;" id="SI_2_pre_inner"></div>
</td>
</tr>
</tbody></table>
</div>
            </div>
    
<!--<table width="355" height="31" border="0" cellpadding="0" cellspacing="0" id="chbox_o_b_n_table" style="margin-top:21px;">
<tr>
<td width="25" height="31" align="left" valign="middle"><input name="" type="checkbox" value="" onchange="F_only_bussiness_name(this.checked)" style="outline:0px;" id="o_b_n_chbx" /></td>
<td width="330" height="31" align="left" valign="middle"><img src="img/dzieba_only_b_n.png" width="174" height="10" onclick="F_only_bussiness_name()" /></td>
</tr>
</table>-->

<div style="width:100%; height:0px; display:none; position:relative; left:0px; top:20px; background-color:#ffe600;" id="error_3">
<div style="width:100%; height:auto; position:absolute; left:0px; bottom:0px; font-family:Sylfaen; font-size:12px; color:#CC0000;" align="left">აირჩიეთ მდებარეობა.</div>
</div>
<div class="row">
    <div class="col">
<table width="355" height="32" border="0" cellpadding="0" cellspacing="0" style="margin-top:20px; display:none;" id="SI_3_table">
<tbody><tr>
<td width="250" height="32" align="left" valign="top"><table width="250" height="32" border="0" cellpadding="0" cellspacing="0" bgcolor="#FFFFFF" id="SI_3_table_in">
<tbody><tr>
<td width="5" height="32" align="left" valign="top" style="background:#FFFFFF url(img/search/input_0_left.png) left no-repeat;"><div style="width:0px; height:0px; position:relative; left:0px; top:0px;">
<img src="img/search/SI_3.png" width="223" height="32" onmousedown="F_DD(event,1)" style="cursor:pointer; position:absolute; left:0px; top:0px;">
</div></td>
<td width="218" height="32" align="center" valign="middle" style="background:transparent url(img/search/input_0_center.png) left repeat-x;">
<form action="" method="post" id="FORM_3" name="FORM_3">
<input type="text" value="აირჩიეთ მდებარეობა..." onfocus="search_start(3,this,'',this.value,'geo')" onblur="search_end(3,this,'',this.value,'geo')" onkeydown="search_pre_select(event,3)" style="width:210px; height:30px; margin:0px; padding:0px 4px 0px 4px; border:0px; background-color:transparent; outline:0px; cursor:text; font-size:14px; font-weight:500; font-family:myfont_m; color:#333333;" id="SI_3" autocomplete="off">
</form>
</td>
<td width="27" height="32" align="left" valign="middle"><img src="img/search/input_1_right.png" width="27" height="32" onmousedown="F_DD(event,1)" style="cursor:pointer;" id="loc_b"></td>
</tr>
<tr>
<td height="0" colspan="3" align="left" valign="top">
<div style="width:250px; height:0px; position:relative; left:0px; top:0px;" id="SI_3_pre_inner"></div>
</td>
</tr>
</tbody></table>

<div style="width:250px; height:0px; position:relative; left:0px; top:0px;">
<div style="width:250px; height:0px; position:absolute; left:0px; top:0px; overflow:hidden; z-index:1000;" id="DD_1_div">

<table width="250" height="65" border="0" cellspacing="0" cellpadding="0" style="position:absolute; left:0px; top:-68px; border-bottom:1px solid #e0e0e0; border-left:1px solid #e0e0e0; border-right:1px solid #e0e0e0;" bgcolor="#FFFFFF" id="DD_1_table">
<tbody><tr>
<td width="248" height="62" align="left" valign="top">

<table width="248" height="63" border="0" cellspacing="0" cellpadding="0">
<tbody><tr>
<td width="224" height="62" align="left" valign="top"><div style="width:220px; height:60px; position:relative; left:2px; top:2px; overflow:hidden; background-color:#F9F9F9;" id="DD_1_list_inner">

<table width="220" border="0" cellspacing="0" cellpadding="0" style="position:absolute; left:0px; top:0px;" id="DD_1_list">
<tbody><tr>
<td align="left" valign="middle" onmouseup="F_select_search_area('სახლი','1')" id="cities_list_in2_geo" style="cursor:pointer; font-size:12px; font-family:myfont_m; color:#333333;">სახლი</td>
</tr>
<tr>
<td align="left" valign="middle" onmouseup="F_select_search_area('სამსახური','2')" id="cities_list_in2_geo" style="cursor:pointer; font-size:12px; font-family:myfont_m; color:#333333;">სამსახური</td>
</tr>
<tr>
<td align="left" valign="middle" onmouseup="F_select_search_area('სხვა','3')" id="cities_list_in2_geo" style="cursor:pointer; font-size:12px; font-family:myfont_m; color:#333333;">სხვა</td>
</tr>
</tbody></table>

</div></td>
<td width="24" height="62" align="left" valign="top" id="DD_1_div_inner">&nbsp;</td>
</tr>
</tbody></table>

</td>
</tr>
</tbody></table>

</div>
</div>

</td>
<td width="105" height="32" align="left" valign="middle">

<img src="img/create_edit.png" onclick="F_create_edit_locations()" title="შექმნა / რედაქტირება" style="cursor:pointer; margin-left:20px;"></td>
</tr>
</tbody></table>


</div> <!--244 col-s dasasruli-->
</div> <!--243 row-s dasasruli-->
</div> <!--125-s col dasasruli-->



<div class="col-md-5 pr-0 mr-0 margin_search d-flex justify-content-md-end justify-content-sm-start">

<div height="42" align="left" valign="top">
    
 <table height="42" border="0" cellpadding="0" cellspacing="0">
<tbody><tr>

<td height="42" align="center" valign="middle" style="background:#FFFFFF" class="city_search_td">
<form action="" method="GET" id="FORM_1" name="FORM_1">
<input type="text" value="თბილისი" onfocus="search_start(1,this,'',this.value,'geo')" onblur="search_end(1,this,'',this.value,'geo')" onkeydown="search_pre_select(event,1)" class="city_search_td" style="height:40px; margin:0px; padding:3px 4px 0px 10px; border:0px; background-color:transparent; outline:0px; cursor:text; font-size:14px; font-weight:500; font-family:myfont_m; color:#333333;" id="SI_1" autocomplete="off">
</form>
</td>
<td width="37" height="42" align="center" valign="middle" bgcolor="#eaeaea" onmousedown="F_DD(event,0)" style="cursor:pointer;"><svg onmousedown="F_DD(event,0)" style="cursor: pointer;" class="svg-inline--fa fa-caret-down fa-w-10" aria-hidden="true" data-prefix="fas" data-icon="caret-down" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 320 512" data-fa-i2svg=""><path fill="currentColor" d="M31.3 192h257.3c17.8 0 26.7 21.5 14.1 34.1L174.1 354.8c-7.8 7.8-20.5 7.8-28.3 0L17.2 226.1C4.6 213.5 13.5 192 31.3 192z"></path></svg><!-- <i onmousedown="F_DD(event,0)" style="cursor:pointer;" class="fas fa-caret-down"></i> --></td>
</tr>
<tr>
<td height="0" colspan="3" align="left" valign="top">
<div style="height:0px; position:relative; left:0px; top:0px;" id="SI_1_pre_inner"></div>
</td>
</tr>
</tbody></table>
    







































<div style="width:0px; height:0px; position:relative; left:0px; top:0px;">

<div style="width:256px; height:1px; position:absolute; left:0px; top:0px; overflow:hidden;" id="DD_0_div">



<table width="250" height="254" border="0" cellspacing="0" cellpadding="0" style="position:absolute; left:0px; top:-258px; border-bottom:1px solid #e0e0e0; border-left:1px solid #e0e0e0; border-right:1px solid #e0e0e0; z-index:100;" id="DD_0_table">
<tbody><tr>
<td width="248" height="254" align="left" valign="top" bgcolor="#FFFFFF">



<table width="248" height="254" border="0" cellspacing="0" cellpadding="0">
<tbody><tr>
<td width="248" height="254" align="left" valign="top" bgcolor="#FFFFFF">

<div style="width:242px; height:250px; position:relative; left:2px; top:2px; overflow:auto; background-color:#F9F9F9;" id="DD_0_list_inner"><table width="220" height="1788" border="0" cellspacing="0" cellpadding="0" style="position:absolute; left:0px; top:0px;" id="DD_0_list"><tbody><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep1','თბილისი')" id="cities_list_in2_geo">თბილისი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('37sepnull','აფხაზეთი')" id="cities_list_in1_geo">აფხაზეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep101','გალი')" id="cities_list_in2_geo">გალი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('7sepnull','აჭარა')" id="cities_list_in1_geo">აჭარა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep10','ბათუმი')" id="cities_list_in2_geo">ბათუმი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep61','ქედა')" id="cities_list_in2_geo">ქედა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep62','ქობულეთი')" id="cities_list_in2_geo">ქობულეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep68','შუახევი')" id="cities_list_in2_geo">შუახევი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep83','ხელვაჩაური')" id="cities_list_in2_geo">ხელვაჩაური</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep86','ხულო')" id="cities_list_in2_geo">ხულო</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep97','ჩაქვი')" id="cities_list_in2_geo">ჩაქვი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('5sepnull','გურია')" id="cities_list_in1_geo">გურია</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep36','ლანჩხუთი')" id="cities_list_in2_geo">ლანჩხუთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep46','ოზურგეთი')" id="cities_list_in2_geo">ოზურგეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep70','ჩოხატაური')" id="cities_list_in2_geo">ჩოხატაური</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep95','ურეკი')" id="cities_list_in2_geo">ურეკი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('3sepnull','იმერეთი')" id="cities_list_in1_geo">იმერეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep11','ბაღდათი')" id="cities_list_in2_geo">ბაღდათი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep26','ვანი')" id="cities_list_in2_geo">ვანი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep27','ზესტაფონი')" id="cities_list_in2_geo">ზესტაფონი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep32','თერჯოლა')" id="cities_list_in2_geo">თერჯოლა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep52','სამტრედია')" id="cities_list_in2_geo">სამტრედია</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep53','საჩხერე')" id="cities_list_in2_geo">საჩხერე</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep58','ტყიბული')" id="cities_list_in2_geo">ტყიბული</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep63','ქუთაისი')" id="cities_list_in2_geo">ქუთაისი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep79','წყალტუბო')" id="cities_list_in2_geo">წყალტუბო</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep80','ჭიათურა')" id="cities_list_in2_geo">ჭიათურა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep81','ხარაგაული')" id="cities_list_in2_geo">ხარაგაული</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep85','ხონი')" id="cities_list_in2_geo">ხონი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('2sepnull','კახეთი')" id="cities_list_in1_geo">კახეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep9','ახმეტა')" id="cities_list_in2_geo">ახმეტა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep22','გურჯაანი')" id="cities_list_in2_geo">გურჯაანი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep23','დედოფლისწყარო')" id="cities_list_in2_geo">დედოფლისწყარო</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep31','თელავი')" id="cities_list_in2_geo">თელავი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep35','ლაგოდეხი')" id="cities_list_in2_geo">ლაგოდეხი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep51','საგარეჯო')" id="cities_list_in2_geo">საგარეჯო</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep55','სიღნაღი')" id="cities_list_in2_geo">სიღნაღი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep66','ყვარელი')" id="cities_list_in2_geo">ყვარელი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep102','წნორი')" id="cities_list_in2_geo">წნორი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('4sepnull','მცხეთა–მთიანეთი')" id="cities_list_in1_geo">მცხეთა–მთიანეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep25','დუშეთი')" id="cities_list_in2_geo">დუშეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep33','თიანეთი')" id="cities_list_in2_geo">თიანეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep44','მცხეთა')" id="cities_list_in2_geo">მცხეთა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep65','ყაზბეგი')" id="cities_list_in2_geo">ყაზბეგი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep93','გუდაური')" id="cities_list_in2_geo">გუდაური</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep98','ახალგორი')" id="cities_list_in2_geo">ახალგორი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('1sepnull','რაჭა-ლეჩხუმი/ქვემო სვანეთი')" id="cities_list_in1_geo">რაჭა-ლეჩხუმი/ქვემო სვანეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep4','ამბროლაური')" id="cities_list_in2_geo">ამბროლაური</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep38','ლენტეხი')" id="cities_list_in2_geo">ლენტეხი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep47','ონი')" id="cities_list_in2_geo">ონი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep72','ცაგერი')" id="cities_list_in2_geo">ცაგერი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('6sepnull','სამეგრელო/ზემო სვანეთი')" id="cities_list_in1_geo">სამეგრელო/ზემო სვანეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep2','აბაშა')" id="cities_list_in2_geo">აბაშა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep29','ზუგდიდი')" id="cities_list_in2_geo">ზუგდიდი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep41','მარტვილი')" id="cities_list_in2_geo">მარტვილი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep43','მესტია')" id="cities_list_in2_geo">მესტია</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep54','სენაკი')" id="cities_list_in2_geo">სენაკი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep59','ფოთი')" id="cities_list_in2_geo">ფოთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep71','ჩხოროწყუ')" id="cities_list_in2_geo">ჩხოროწყუ</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep75','წალენჯიხა')" id="cities_list_in2_geo">წალენჯიხა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep84','ხობი')" id="cities_list_in2_geo">ხობი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep92','ანაკლია')" id="cities_list_in2_geo">ანაკლია</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep100','ჯვარი')" id="cities_list_in2_geo">ჯვარი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('26sepnull','სამცხე–ჯავახეთი')" id="cities_list_in1_geo">სამცხე–ჯავახეთი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep3','ადიგენი')" id="cities_list_in2_geo">ადიგენი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep5','ასპინძა')" id="cities_list_in2_geo">ასპინძა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep7','ახალქალაქი')" id="cities_list_in2_geo">ახალქალაქი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep8','ახალციხე')" id="cities_list_in2_geo">ახალციხე</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep14','ბორჯომი')" id="cities_list_in2_geo">ბორჯომი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep45','ნინოწმინდა')" id="cities_list_in2_geo">ნინოწმინდა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep90','აბასთუმანი')" id="cities_list_in2_geo">აბასთუმანი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep91','ბაკურიანი')" id="cities_list_in2_geo">ბაკურიანი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep99','ვალე')" id="cities_list_in2_geo">ვალე</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('22sepnull','ქვემო ქართლი')" id="cities_list_in1_geo">ქვემო ქართლი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep13','ბოლნისი')" id="cities_list_in2_geo">ბოლნისი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep17','გარდაბანი')" id="cities_list_in2_geo">გარდაბანი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep24','დმანისი')" id="cities_list_in2_geo">დმანისი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep30','თეთრიწყარო')" id="cities_list_in2_geo">თეთრიწყარო</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep40','მარნეული')" id="cities_list_in2_geo">მარნეული</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep50','რუსთავი')" id="cities_list_in2_geo">რუსთავი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep76','წალკა')" id="cities_list_in2_geo">წალკა</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('23sepnull','შიდა ქართლი')" id="cities_list_in1_geo">შიდა ქართლი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep19','გორი')" id="cities_list_in2_geo">გორი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep34','კასპი')" id="cities_list_in2_geo">კასპი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep60','ქარელი')" id="cities_list_in2_geo">ქარელი</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('nullsep82','ხაშური')" id="cities_list_in2_geo">ხაშური</td></tr><tr><td align="left" valign="middle" onmouseup="F_select_region_city('36sepnull','საქართველო')" id="cities_list_in1_geo">საქართველო</td></tr></tbody></table></div>

</td>
</tr>
</tbody></table>



</td>
</tr>
</tbody></table>



</div>

</div>




































</div>




<div class="search_margin_left" style="height: 42px;">
<input name="this_file" type="hidden" id="this_file" value="companies">
<form action="search.php" method="get" id="search_form">
<input name="file" type="hidden" id="G_file" value="">
<input name="rub" type="hidden" id="G_rub" value="445">
<input name="lan" type="hidden" id="G_lan" value="geo">
<input name="S_lan" type="hidden" id="G_S_lan" value="geo">
<input name="s_b" type="hidden" id="G_s_b" value="1">
<input name="o_b_n" type="hidden" id="G_o_b_n" value="0">
<input name="sh_o_m" type="hidden" id="G_sh_o_m" value="0">
<input name="SI_0" type="hidden" id="G_SI_0" value="კომპანიის სახელი ან საქმიანობა">
<input name="SI_1" type="hidden" id="G_SI_1" value="თბილისი">
<input name="city_id" type="hidden" id="G_city_id" value="null">
<input name="SI_2" type="hidden" id="G_SI_2" value="ქუჩა">
<input name="SI_3" type="hidden" id="G_SI_3" value="0">
<input name="lat" type="hidden" id="G_lat" value="0">
<input name="lon" type="hidden" id="G_lon" value="0">
<input name="SR_pg" type="hidden" id="G_SR_pg" value="1">
<input name="filter" type="hidden" id="G_filter" value="0000000">
<input name="sort" type="hidden" id="G_sort" value="PR">

<input name="filter_cat" type="hidden" id="G_filter_cat" value="0">

<input name="letter" type="hidden" id="G_letter" value="">

<input name="ubani" type="hidden" id="G_ubani" value="">

</form>
<!--<img src="img/search_button_geo.png" width="81" height="32" onClick="F_search_form()" style=" cursor:pointer;" />-->



<div style="width:76px; height:42px; line-height:42px; background-color:#333333; background-image:url(img/mag_index.png); background-position:left; background-repeat:no-repeat; border-radius:1px; font-family:myfont_m; font-size:13px; font-weight:500; color:#F0F0F0; padding-left: 30px; padding-right:10px; cursor:pointer; letter-spacing:0px;" onclick="F_search_form();" onmousedown="return false;">ძიება</div>



</div>
</div> <!--339 div-is dasasruli-->

</div> <!--form_0 rows dasasruli, ickeba 108-ze-->

</div>

</div>





















<style>
    @media screen and (max-width: 969px) {
   .popular_margin
   {
      margin-right: 3px;
      
   }
                  
    .popular_word
    {
        display: none!important;
    }
    
    
   }
   
    @media screen and (min-width: 970px) {
   .popular_margin
   {
      margin-right: 15px;
      
   }
   }
    
</style>
<div class="container-fluid d-none d-md-block" style="background:#eaeaea;">
    <div class="container p-0" style="max-width:960px;"> 
<div class="links1-table" style="margin-top:10px;" id="links1">

<div class="row m-0 p-0" style="max-width:960px;">


<div class="col-10 mx-0 px-0" style="height: 52px; padding-top: 10px;">





<div class="popular_margin popular_word" style="display: inline-block; font-family:myfont_m; font-size:12px; font-weight:normal; color:#4d4d4d;">პოპულარული: </div>


<div class="popular_margin" style="display: inline-block;">
<a href="resto.php" style="cursor: pointer; font-family: myfont_m; font-size: 12px; font-weight: normal; color: rgb(77, 77, 77); padding: 6px 6px 6px 24px; background: url(&quot;img/pr_restaurants.png&quot;) 6px center no-repeat transparent; border: 1px solid transparent; border-radius: 3px; text-transform: uppercase; white-space: nowrap;" onmouseover="this.style.backgroundColor='#fff101';this.style.border='1px solid #d9ce00';" onmouseout="this.style.backgroundColor='transparent';this.style.border='1px solid transparent';">რესტორნები</a>
</div>


<div class="popular_margin" style="display: inline-block; " align="left" valign="middle">


<a href="companies.php?lan=geo&amp;rub=428" style="cursor:pointer; font-family:myfont_m; font-size:12px; font-weight:normal; color:#4d4d4d; padding:6px 6px 6px 29px; background:url(img/pr_taxi.png) 6px no-repeat; border:1px solid transparent; border-radius:3px; text-transform:uppercase;" onmouseover="this.style.backgroundColor='#fff101';this.style.border='1px solid #d9ce00';" onmouseout="this.style.backgroundColor='transparent';this.style.border='1px solid transparent';">
       ტაქსი</a>

</div>
<div class="popular_margin" style="display: inline-block; " align="left" valign="middle">


<a href="companies.php?lan=geo&amp;rub=445" style="cursor:pointer; font-family:myfont_m; font-size:12px; font-weight:normal; color:#4d4d4d; padding:6px 6px 6px 29px; background:url(img/pr_tourism.png) 6px no-repeat; border:1px solid transparent; border-radius:3px; text-transform:uppercase;" onmouseover="this.style.backgroundColor='#fff101';this.style.border='1px solid #d9ce00';" onmouseout="this.style.backgroundColor='transparent';this.style.border='1px solid transparent';">
       ტურიზმი</a>

</div>
<div class="popular_margin" style="display: inline-block; " align="left" valign="middle">


<a href="companies.php?lan=geo&amp;rub=367" style="cursor:pointer; font-family:myfont_m; font-size:12px; font-weight:normal; color:#4d4d4d; padding:6px 6px 6px 26px; background:url(img/pr_hotels.png) 6px no-repeat; border:1px solid transparent; border-radius:3px; text-transform:uppercase;" onmouseover="this.style.backgroundColor='#fff101';this.style.border='1px solid #d9ce00';" onmouseout="this.style.backgroundColor='transparent';this.style.border='1px solid transparent';">
       სასტუმროები</a>

</div>
<div class="popular_margin" style="display: inline-block; " align="left" valign="middle">


<a href="companies.php?lan=geo&amp;rub=174" style="cursor:pointer; font-family:myfont_m; font-size:12px; font-weight:normal; color:#4d4d4d; padding:6px 6px 6px 29px; background:url(img/pr_medicine.png) 6px no-repeat; border:1px solid transparent; border-radius:3px; text-transform:uppercase;" onmouseover="this.style.backgroundColor='#fff101';this.style.border='1px solid #d9ce00';" onmouseout="this.style.backgroundColor='transparent';this.style.border='1px solid transparent';">
       კლინიკები	</a>

</div>
<div class="popular_margin" style="display: inline-block; " align="left" valign="middle">


<a href="companies.php?lan=geo&amp;rub=51" style="cursor:pointer; font-family:myfont_m; font-size:12px; font-weight:normal; color:#4d4d4d; padding:6px 6px 6px 21px; background:url(img/pr_pharmacies.png) 6px no-repeat; border:1px solid transparent; border-radius:3px; text-transform:uppercase;" onmouseover="this.style.backgroundColor='#fff101';this.style.border='1px solid #d9ce00';" onmouseout="this.style.backgroundColor='transparent';this.style.border='1px solid transparent';">
       აფთიაქები</a>

</div>




</div>

<div class="col-2 mr-0 pr-0 d-flex justify-content-end">

<div style="display: inline-block;">

<noscript>
<div align="center" style="width:200px; height:100px; line-height:100px; background-color:#0099CC; color:#333333; font-family:Arial; font-weight:bold; font-size:18px;">Noscript</div>
</noscript>

<table height="52" border="0" cellpadding="0" cellspacing="0">
<tbody><tr>




<!--<td align="right" valign="middle" bgcolor="#0099CC"><a style="font-family:myfont_m; font-size:13px; font-weight:bold; color:#005e9d; background:transparent url(img/signup_icon.png) left no-repeat; padding-left:20px; margin:0px 0px 0px 20px;" onclick="F_login_form_display();">ავტორიზაცია</a></td>-->


<td align="right" valign="middle">
<a id="shesvla_" onclick="if(document.getElementById('login_table').style.display=='none'){document.getElementById('login_table').style.display='';this.style.backgroundImage='url(img/login_form_display_icon_o.png)';}else{document.getElementById('login_table').style.display='none';this.style.backgroundImage='url(img/login_form_display_icon_c.png)';};return false;" onmousedown="return false;" style="font-family:myfont_m; font-size:13px; font-weight:bold; cursor:pointer; padding-left:20px; margin:0px 0px 0px 20px; background-color:transparent; background-image:url(img/login_form_display_icon_c.png); background-position:left; background-repeat:no-repeat; color:#005E9D;">შესვლა</a>


<table border="0" cellspacing="0" cellpadding="0" style="width:100%; height:100%; background-color:rgba(0,0,0,0.5); position:fixed; left:0px; top:0px; z-index:10002; display:none;" id="login_table">
<tbody><tr>
<td align="center" valign="middle" style="width:100%; height:100px;" id="login_table_">

<!--<div style="background-color:#999999; width:0px; height:0px; position:relative; right:0px; top:28px; z-index:1000;">
<div style="width:265px; height:0px; position:absolute; right:0px; top:0px; z-index:1000;">-->
<table width="265" border="0" cellspacing="10" cellpadding="0" style="border:1px solid #BBBBBB; background-color:#FFFFFF; box-shadow:0px 2px 6px rgba(0,0,0,0.4);" id="login_table">
<tbody><tr>
<td width="243" align="center" valign="middle">

<form action="login.php" method="post" style="margin:0px; padding:0px;">
<table width="243" border="0" cellpadding="0" cellspacing="0">

<tbody><tr>
<td width="243" align="right" valign="middle" id="login_table_"><img src="img/close_2.png" width="12" height="12" alt="" style="margin-top: 10px; cursor:pointer;" onmouseover="this.src='img/close_1.png';" onmouseout="this.src='img/close_2.png';" onclick="document.getElementById('login_table').style.display='none';document.getElementById('shesvla_').style.backgroundImage='url(img/login_form_display_icon_c.png)';" id="login_table_"></td>
</tr>

<tr>
<td width="243" height="115" align="center" valign="middle" id="login_table_"><img src="img/login_user_icon.png" name="login_table_" width="85" height="85" id="login_table_" style="margin-bottom:10px;"></td>
</tr>
<!--<tr>
<td width="243" height="30" align="left" valign="bottom" style="font-family:myfont_m; font-size:13px; cursor:default;" id="login_table_">ელ-ფოსტა</td>
</tr>-->
<tr>
<td width="243" align="center" valign="middle" id="login_table_"><div align="left" style="width:223px; height:28px; position:relative; left:0px; top:0px;">
<input name="email" id="login_email" type="text" value="ელ-ფოსტა" style="width:223px; font-size: 14px; height:26px; position:absolute; left:0px; top:0px; padding:0px 6px 0px 40px; margin:0px; border:1px solid #c7c7c7; color:#666666; cursor:text; z-index:10;" onfocus="
this.style.border='1px solid #f0e037';
if(this.value=='ელ-ფოსტა'){this.value='';}
" onblur="
this.style.border='1px solid #c7c7c7';
if(this.value==''){this.value='ელ-ფოსტა';}
">
<img src="img/login_input_email_l.png" width="38" height="28" style="position:absolute; left:0px; top:0px; cursor:default; z-index:11;" id="login_table_">
</div></td>
</tr>
<tr>
<td width="243" height="14" align="left" valign="bottom" style="font-family:myfont_m; font-size:13px; cursor:default;" id="login_table_"><!--პაროლი--></td>
</tr>
<tr>
<td width="243" align="center" valign="middle" id="login_table_">

<div style="width:223px; height:28px; position:relative; left:0px; top:0px;">

<div align="left" style="width:223px; height:28px; position:relative; left:0px; top:0px; margin-top:0px; z-index:10;" id="pass_box">
<table width="223" height="28" border="0" cellpadding="0" cellspacing="0" style="border:1px solid #c7c7c7; background-color:#FFFFFF; position:absolute; left:0px; top:0px; z-index:0;" id="pass_border">
<tbody><tr><td width="221" height="26"></td></tr>
</tbody></table>
<div style="width:175px; height:auto; margin:0px; padding:6px 8px 6px 40px; background:transparent; border:none; outline:none; cursor:text; font-family:sylfaen; font-size:14px; color:#666666; position:absolute; left:0px; top:0px; z-index:1;" align="left" id="pass_def_val">პაროლი</div>
<input style="width:223px; height:auto; margin:0px; padding:6px 8px 6px 40px; background:transparent; border:none; outline:none; cursor:text; font-family:Arial; font-size:14px; position:absolute; left:0px; top:0px; z-index:2;" name="pass" id="login_pass" type="password" value="" onfocus="document.getElementById('pass_def_val').innerHTML='';document.getElementById('pass_border').style.border='1px solid #f0e037';" onblur="if(this.value==''){document.getElementById('pass_def_val').innerHTML='პაროლი';}document.getElementById('pass_border').style.border='1px solid #c7c7c7';">
</div>
<img src="img/login_input_pass_l.png" width="38" height="28" style="position:absolute; left:0px; top:0px; cursor:default; z-index:11;" id="login_table_">
</div>







</td>
</tr>
<tr>
<td width="243" height="20" align="left" valign="bottom" id="login_table_"><a href="forgot_password.php?lan=geo" style="font-family:sylfaen; font-size:11px; text-decoration:none; color:#005e9d; cursor:pointer; margin-left:10px;" id="login_table_">დაგავიწყდათ პაროლი?</a></td>
</tr>
<tr>
<td width="243" height="14" style="line-height:14px;" id="login_table_"></td>
</tr>
<tr>
<td width="243" height="26" align="center" valign="middle" id="login_table_"><table width="223" height="26" border="0" cellpadding="0" cellspacing="0">
<tbody><tr>
<td width="143" height="26" align="left" id="login_table_"><a id="login_table_" style="background:transparent url(img/remember_0.png) left no-repeat; font-family:sylfaen; font-size:11px; color:#333333; cursor:pointer; padding-left:44px; padding-bottom:2px; padding-top:2px; letter-spacing:0px;" onclick="F_remember(this,'save');" onmousedown="return false;">დამიმახსოვრე</a><input name="save" id="save" type="hidden" value="0" style="width:30px;">
<!--<label onmousedown="return false;" id="login_table_"><input name="save" id="login_table_" type="checkbox" value="1" />დამიმახსოვრე</label>--></td>
<td width="80" height="26" align="left" valign="top" bgcolor="#838383"><input name="submit" type="submit" value="შესვლა" style="width:80px; height:26px; padding:0px; margin:0px; border:none; outline:none; cursor:pointer; background-color:#ffe900; font-family:myfont_m_normal; font-size:14px; font-weight: bold; color:black; letter-spacing:0px;line-height: 30px;" id="login_table_"></td>
</tr>
</tbody></table></td>
</tr>
</tbody></table>
</form>


<table width="243" border="0" cellpadding="0" cellspacing="0">
<tbody><tr>
<td width="243" height="14" style="line-height:14px;" id="login_table_"></td>
</tr>
<tr>
<td align="center" valign="top" width="243" height="10" style="line-height:10px;" id="login_table_">

<div style="width:223px; height:1px; border-top:1px solid #e0e0e0;" id="login_table_"></div>

</td>
</tr>
<tr>
<td width="243" height="46" align="center" valign="top" id="login_table_" style="line-height:14px;"><table width="223" border="0" cellspacing="0" cellpadding="0">
<tbody><tr>
<td width="110" height="26" align="left" valign="top" id="login_table_" style="border-right:3px solid #FFFFFF;"><a href="registration_form.php?lan=geo" style="text-decoration:none; margin:0px; padding:0px;">
<div align="center" style="width:110px; height:26px; line-height:29px; cursor:pointer; background-color:#8f7f58; font-family:myfont_m; font-size:13px; color:#ffffff; overflow:hidden;" id="login_table_">რეგისტრაცია</div></a></td>
<td width="113" align="right" valign="top" id="login_table_"><!--if($IsAccess)-->

<a href="https://www.facebook.com/v2.5/dialog/oauth?client_id=352670461544148&amp;state=c1e24b07336866d872e9927f66778316&amp;response_type=code&amp;sdk=php-sdk-5.6.1&amp;redirect_uri=https%3A%2F%2Fwww.yell.ge%2Ffb-callback.php&amp;scope=email" style="text-decoration:none; margin:0px; padding:0px;">
    	<img src="img/login_with_facebook_geo.gif" name="login_table_" width="110" height="26" id="login_table_" style="border:none; cursor:pointer;">
</a>
<!--<a href="login_facebook.php?fn=//companies.php&lan=geo&rub=445" 
	style="text-decoration:none; margin:0px; padding:0px;">
    	<img src="img/login_with_facebook//_geo.gif" name="login_table_" 
        width="110" height="26" id="login_table_" style="border:none; cursor:pointer;" />
</a>-->

</td>
</tr>
</tbody></table></td>
</tr>
<tr>
<td width="243" height="0" style="line-height:0px;" id="login_table_"></td>
</tr>
</tbody></table>


</td>
</tr>
</tbody></table>
<!--</div>
</div>-->

</td>
</tr>
</tbody></table>






</td>












</tr>
</tbody></table>

</div>

</div>
</div>


</div>
        
    
    </div>
</div>







<!--<table width="960" border="0" align="center" cellpadding="0" cellspacing="20" style="border:1px solid #298bcc; background-color:#f2faff; margin-top:50px;">
<tr>
<td width="60" height="60"><img src="img/info_icon.png" width="60" height="60" /></td>
<td align="left" valign="middle" style="font-family:myfont_m; font-size:16px; color:#005e9d;">ინფორმაციის სანახავად გთხოვთ დააჭიროთ ღილაკს ძიება.</td>
</tr>
</table>-->



    
    <div class="container mt-2 p-0" style="max-width: 960px;" id="web_body">
    <div class="row m-0">
        
        
<div class="col-md-3 p-0 mr-1 ml-4 d-flex order-lg-2 order-xl-2" style="max-width: 280px;">
    <div>
        <div class="d-none" style="height: 125px; "><!--<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />--><style>
 #goto_large_map {
    -webkit-box-flex: 0;
    -ms-flex: 0 0 auto;
    flex: 0 0 auto;
    width: auto;
    position: relative;
    top: -80px;
    left: 0px;
    top: -80px;

    text-align: center;
    width: 100%;
}
#btn_goto_large_map{
    width: 110px;
    cursor: pointer;
}
</style>



<div>
    <div id="map_canvas" style="width: 250px; height: 125px; display:none;" align="left"></div>
    <div id="map_canvas_image" style="width: 250px; height: 125px" align="left">
        <img style="height:125px;width:100%;" src="img/map_pict.jpg"> 
    </div>
    <div id="goto_large_map">
        <img src="img/view_on_map.jpg" id="btn_goto_large_map" onclick="F_change_to_large_map()">
    </div>
</div>

<div id="goto_large_map_2" style="display: none;">
    <img src="img/view_on_map.jpg" id="btn_goto_large_map" onclick="F_change_to_large_map()">
</div></div>

    <div style="display: inline-block; margin-bottom: 10px;">


            
</div>

<div style="display: inline-block; margin-top:10px;">


            
</div>

<div style="display: inline-block; margin-top:10px;">


            
</div>

<div style="display: inline-block; margin-top:10px;">


            
</div>
</div>
</div>
   
    <div class="col-md-9 m-0 px-0" style="max-width: 680px;">
        
        <div style="max-width:680px; height:4px; background-color:#E8E8E8;"></div>

            <!--<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />-->






<div class="row pt-1 px-0 mx-0 mb-4" style="max-width: 678px; min-height: 52px; background-color: #f8f8f8;" id="result_count_2020">
<div class="col-9 m-0 px-2 py-0">

<span style="font-family:myfont_m; font-size:14px; color:#000000; font-weight:bold;">
ტურისტული კომპანიები,</span>

<span style="font-family:myfont_m; font-size:13px; color:#000000; font-weight:bold;">
თბილისი</span>


</div>
<div class="col-3 m-0 pr-2 py-0 d-flex justify-content-end">

<div style="padding-right: 5px; font-family:Sylfaen; font-size:12px; color:#005e9d;">რეზულტატი: </div>
<div style="padding-right: 5px; font-family:Tahoma; font-size:12px; color:#005e9d;">200</div>

</div>
</div>













            



















<!--SmartPhone Filter-->
<div class="row m-2 d-block d-sm-none">
    <div data-toggle="modal" data-target="#filterModal" style="display: inline-block; width: 100px; height: 30px; margin-top: 2px; border: 1px solid gray; cursor:pointer; font-family:myfont_m; font-size:12px; color:#005e9d; padding:7px 15px 0px 10px;" id="SR_filter_tab_1_td"><svg class="svg-inline--fa fa-sliders-h fa-w-16" style="color: #696969; margin-top: 2px; margin-right: 3px;" aria-hidden="true" data-prefix="fas" data-icon="sliders-h" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512" data-fa-i2svg=""><path fill="currentColor" d="M496 384H160v-16c0-8.8-7.2-16-16-16h-32c-8.8 0-16 7.2-16 16v16H16c-8.8 0-16 7.2-16 16v32c0 8.8 7.2 16 16 16h80v16c0 8.8 7.2 16 16 16h32c8.8 0 16-7.2 16-16v-16h336c8.8 0 16-7.2 16-16v-32c0-8.8-7.2-16-16-16zm0-160h-80v-16c0-8.8-7.2-16-16-16h-32c-8.8 0-16 7.2-16 16v16H16c-8.8 0-16 7.2-16 16v32c0 8.8 7.2 16 16 16h336v16c0 8.8 7.2 16 16 16h32c8.8 0 16-7.2 16-16v-16h80c8.8 0 16-7.2 16-16v-32c0-8.8-7.2-16-16-16zm0-160H288V48c0-8.8-7.2-16-16-16h-32c-8.8 0-16 7.2-16 16v16H16C7.2 64 0 71.2 0 80v32c0 8.8 7.2 16 16 16h208v16c0 8.8 7.2 16 16 16h32c8.8 0 16-7.2 16-16v-16h208c8.8 0 16-7.2 16-16V80c0-8.8-7.2-16-16-16z"></path></svg><!-- <i class="fas fa-sliders-h" style="color: #696969; margin-top: 2px; margin-right: 3px;"></i> -->
ფილტრი</div>
  
    <div data-toggle="modal" data-target="#sortirebaModal" style="display: inline-block; margin-top: 2px;width: 100px; height: 30px; border: 1px solid gray; cursor:pointer; font-family:myfont_m; font-size:12px; color:#005e9d; padding:7px 20px 0px 10px; white-space:nowrap;">
<svg class="svg-inline--fa fa-sort fa-w-10" style="color: #696969; margin-top: 2px; margin-right: 3px;" aria-hidden="true" data-prefix="fas" data-icon="sort" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 320 512" data-fa-i2svg=""><path fill="currentColor" d="M41 288h238c21.4 0 32.1 25.9 17 41L177 448c-9.4 9.4-24.6 9.4-33.9 0L24 329c-15.1-15.1-4.4-41 17-41zm255-105L177 64c-9.4-9.4-24.6-9.4-33.9 0L24 183c-15.1 15.1-4.4 41 17 41h238c21.4 0 32.1-25.9 17-41z"></path></svg><!-- <i class="fas fa-sort" style="color: #696969; margin-top: 2px; margin-right: 3px;"></i> -->სორტირება</div>
    
    <div onclick="F_change_to_large_map()" style="display: inline-block; width: 70px; height: 30px; margin-top: 2px; border: 1px solid gray; cursor:pointer; font-family:myfont_m; font-size:12px; color:#005e9d; padding:7px 5px 0px 15px;"><svg class="svg-inline--fa fa-map-marker-alt fa-w-12" style="color: #696969; margin-top: 2px; margin-right: 2px;" aria-hidden="true" data-prefix="fas" data-icon="map-marker-alt" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 384 512" data-fa-i2svg=""><path fill="currentColor" d="M172.268 501.67C26.97 291.031 0 269.413 0 192 0 85.961 85.961 0 192 0s192 85.961 192 192c0 77.413-26.97 99.031-172.268 309.67-9.535 13.774-29.93 13.773-39.464 0zM192 272c44.183 0 80-35.817 80-80s-35.817-80-80-80-80 35.817-80 80 35.817 80 80 80z"></path></svg><!-- <i class="fas fa-map-marker-alt" style="color: #696969; margin-top: 2px; margin-right: 2px;"></i> --> რუკა</div>
</div>
<!--SmartPhone Filter-->

<div class="modal" id="filterModal">
  <div class="modal-dialog-scrollable">
    <div class="modal-content">

      <!-- Modal Header -->
      <div class="modal-header">
        <div class="modal-title" style="color:#005e9d; font-family: myfont_m; font-size:18px;"><svg class="svg-inline--fa fa-sliders-h fa-w-16" style="color: #696969; margin-top: 5px; margin-right: 7px;" aria-hidden="true" data-prefix="fas" data-icon="sliders-h" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512" data-fa-i2svg=""><path fill="currentColor" d="M496 384H160v-16c0-8.8-7.2-16-16-16h-32c-8.8 0-16 7.2-16 16v16H16c-8.8 0-16 7.2-16 16v32c0 8.8 7.2 16 16 16h80v16c0 8.8 7.2 16 16 16h32c8.8 0 16-7.2 16-16v-16h336c8.8 0 16-7.2 16-16v-32c0-8.8-7.2-16-16-16zm0-160h-80v-16c0-8.8-7.2-16-16-16h-32c-8.8 0-16 7.2-16 16v16H16c-8.8 0-16 7.2-16 16v32c0 8.8 7.2 16 16 16h336v16c0 8.8 7.2 16 16 16h32c8.8 0 16-7.2 16-16v-16h80c8.8 0 16-7.2 16-16v-32c0-8.8-7.2-16-16-16zm0-160H288V48c0-8.8-7.2-16-16-16h-32c-8.8 0-16 7.2-16 16v16H16C7.2 64 0 71.2 0 80v32c0 8.8 7.2 16 16 16h208v16c0 8.8 7.2 16 16 16h32c8.8 0 16-7.2 16-16v-16h208c8.8 0 16-7.2 16-16V80c0-8.8-7.2-16-16-16z"></path></svg><!-- <i class="fas fa-sliders-h" style="color: #696969; margin-top: 5px; margin-right: 7px;"></i> -->ფილტრი</div>
        <button type="button" class="close" data-dismiss="modal">×</button>
      </div>

      <!-- Modal body -->
      <div class="modal-body">

<div align="left" class="SR_filter_div_1_fal">
<div align="left" class="SR_filter_div_2_fal" style="background:transparent url(img/video_icon_2.png) 40px no-repeat; font-family:myfont_m;" onclick="F_change_SR_filter_will('SR_filter_video')">ფოტო<input name="" type="hidden" value="0" id="SR_filter_video" style="width:20px;"></div>
</div>

<div align="left" class="SR_filter_div_1_fal">
<div align="left" class="SR_filter_div_2_fal" style="background:transparent url(img/map_icon_2.png) 40px no-repeat; font-family:myfont_m;" onclick="F_change_SR_filter_will('SR_filter_map')">რუკა<input name="" type="hidden" value="0" id="SR_filter_map" style="width:20px;"></div>
</div>

<div align="left" class="SR_filter_div_1_fal">
<div align="left" class="SR_filter_div_2_fal" style="background:transparent url(img/web_icon_2.png) 40px no-repeat; font-family:myfont_m;" onclick="F_change_SR_filter_will('SR_filter_web')">ვებგვერდი<input name="" type="hidden" value="0" id="SR_filter_web" style="width:20px;"></div>
</div>
          
<div align="left" class="SR_filter_div_1_fal">
<div align="left" class="SR_filter_div_2_fal" style="background:transparent url(img/email_icon_2.png) 40px no-repeat; font-family:myfont_m;" onclick="F_change_SR_filter_will('SR_filter_email')">ელ-ფოსტა<input name="" type="hidden" value="0" id="SR_filter_email" style="width:20px;"></div>
</div>
          

<div align="left" class="SR_filter_div_1_dis">
<div align="left" class="SR_filter_div_2_dis" style="background:transparent url(img/coupon_icon_2.png) 40px no-repeat; font-family:myfont_m;">აქციები</div>
</div>

<!--kalakebi, ubnebi start-->

 
<div style="margin-top: 10px;" align="left" valign="top" bgcolor="#f3f3f3"><div align="left" style="width:100%; height:32px; line-height:32px; font-family:myfont_m; font-size:17px; text-indent:5px; color:#005e9d;">ქალაქები</div>
<div style="width:100%; height:auto; max-height:175px;">
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:5px; color:#000000; cursor:pointer;" onclick="F_change_region_city_from_list('თბილისი',1)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">თბილისი</div>
</div>
<div align="left" style="width:100%; height:32px; line-height:32px; font-family:myfont_m; font-size:14px; text-indent:5px; color:#005e9d;">ახლომდებარე ქალაქები</div>
<div style="width:100%; height:auto; max-height:175px;">
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:5px; color:#000000; cursor:pointer;" onclick="F_change_region_city_from_list('მცხეთა',44)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">მცხეთა</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:5px; color:#000000; cursor:pointer;" onclick="F_change_region_city_from_list('რუსთავი',50)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">რუსთავი</div>
</div>
</div>

<div style="margin-top: 10px;s" align="left" valign="top" bgcolor="#f3f3f3"><div align="left" style="width:100%; height:32px; line-height:32px; font-family:myfont_m; font-size:17px; text-indent:5px; color:#005e9d;">უბნები</div>
<div style="width:100%; height:auto; max-height:175px;">
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ავლაბარი, მეტრომშენი',52)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ავლაბარი, მეტრომშენი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('გლდანი',42)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">გლდანი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('დიდი დიღომი',61)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">დიდი დიღომი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('დიდუბე',46)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">დიდუბე</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('დიღომი',162)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">დიღომი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ვაზისუბანი, მე–8 ლეგიონი',54)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ვაზისუბანი, მე–8 ლეგიონი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ვაკე, ბაგები',44)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ვაკე, ბაგები</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ვარკეთილი',47)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ვარკეთილი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ვერა',25)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ვერა</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('მთაწმინდა',43)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">მთაწმინდა</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('მუხიანი',50)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">მუხიანი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ნავთლუღი, წმ. ბარბარეს უბანი(ზმკ)',105)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ნავთლუღი, წმ. ბარბარეს უბანი(ზმკ)</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ნაძალადევი',57)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ნაძალადევი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ორთაჭალა',123)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ორთაჭალა</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ორხევი, ლილო, აეროპორტი',55)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ორხევი, ლილო, აეროპორტი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('საბურთალო',62)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">საბურთალო</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('საბურთალო: დელისი, ვეძისი, ვაჟა, ნუცუბიძე',142)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">საბურთალო: დელისი, ვეძისი, ვაჟა, ნუცუბიძე</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('სოლოლაკი',53)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">სოლოლაკი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ჩუღურეთი ქვემო',49)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ჩუღურეთი ქვემო</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:5px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ძველი თბილისი (კალაუბანი, აბანოთუბანი)',103)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ძველი თბილისი (კალაუბანი, აბანოთუბანი)</div>
</div>
</div>

<!--kalakebi, ubnebi end-->

          

      </div>

      <!-- Modal footer -->
      <div class="modal-footer">
        <button style="background-color: #ffed00" type="button" class="btn" data-dismiss="modal">Close</button>
      </div>

    </div>
  </div>
</div>

<style>
    
    .sortireba_mob
    {
    cursor:pointer; 
    font-size:14px; 
    
    height: 25px;
    margin-bottom: 5px;
        
    }
  </style>


<!--Sortireba Modal start-->
<div class="modal" id="sortirebaModal">
  <div class="modal-dialog">
    <div class="modal-content">

      <!-- Modal Header -->
      <div class="modal-header">
        <div class="modal-title" style="color:#005e9d; font-family: myfont_m; font-size:18px;"><svg class="svg-inline--fa fa-sort fa-w-10" style="color: #696969; margin-top: 2px; margin-right: 7px;" aria-hidden="true" data-prefix="fas" data-icon="sort" role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 320 512" data-fa-i2svg=""><path fill="currentColor" d="M41 288h238c21.4 0 32.1 25.9 17 41L177 448c-9.4 9.4-24.6 9.4-33.9 0L24 329c-15.1-15.1-4.4-41 17-41zm255-105L177 64c-9.4-9.4-24.6-9.4-33.9 0L24 183c-15.1 15.1-4.4 41 17 41h238c21.4 0 32.1-25.9 17-41z"></path></svg><!-- <i class="fas fa-sort" style="color: #696969; margin-top: 2px; margin-right: 7px;"></i> -->სორტირება</div>
        <button type="button" class="close" data-dismiss="modal">×</button>
      </div>
      <div>
      <!-- Modal body -->
      <div class="modal-body pb-0">

     
<div class="sortireba_mob" style="font-family:myfont_m; color:#000000;" onclick="F_change_SR_sort('PR');">&nbsp;&nbsp;პრიორიტეტულად</div>
<div class="sortireba_mob" style="font-family:myfont_m; color:#005e9d;" onclick="F_change_SR_sort('AL');">&nbsp;&nbsp;ანბანურად</div>
<div class="sortireba_mob" style="font-family:myfont_m; color:#005e9d;" onclick="F_change_SR_sort('RT');">&nbsp;&nbsp;რეიტინგით</div>
<div class="sortireba_mob" style="font-family:myfont_m; color:#005e9d;" onclick="F_change_SR_sort('RV');">&nbsp;&nbsp;რევიუ</div>


    </div>

      </div>

      <div class="modal-footer">
        <button style="background-color: #ffed00" type="button" class="btn" data-dismiss="modal">Close</button>
      </div>
      
  </div>
    </div>
  </div>

<!--Sortireba Modal end-->

<div class="row p-0 mx-0 mt-3" style="max-width: 678px;">


    <div class="d-none d-sm-block" style="display: inline-block; height:30px; margin-left:0px; top:1px; border-top:1px solid #d9d9d9; border-right:1px solid #d9d9d9; border-bottom:1px solid #d9d9d9; border-left:1px solid #d9d9d9; background-color:#efefef;" id="SR_filter_tab_1_table">

        <div style="cursor:pointer; font-family:myfont_m; font-size:12px; color:#000000; padding:7px 20px 0px 10px; background:url(img/arrow_down_1.png) right no-repeat;" onclick="F_change_SR_filter_tab(1);" onmousedown="return false;" id="SR_filter_tab_1_td">ფილტრი</div>

    </div>


    <div class="d-none d-sm-block" style="display: inline-block; height:30px; margin-left:0px; top:1px; border-top:1px solid #d9d9d9; border-right:1px solid #d9d9d9; border-bottom:1px solid #d9d9d9; border-left:1px solid #d9d9d9; background-color:#efefef;" id="SR_filter_tab_3_table">

        <div style="cursor:pointer; font-family:myfont_m; font-size:12px; color:#000000; padding:7px 20px 0px 10px; background:url(img/arrow_down_1.png) right no-repeat; white-space:nowrap;" onclick="F_change_SR_filter_tab(3);" onmousedown="return false;" id="SR_filter_tab_3_td">ქალაქები/უბნები</div>

    </div>


    <div class="d-none d-sm-block" style="display: inline-block; height:30px; margin-left:0px; top:1px; border-top:1px solid #d9d9d9; border-right:1px solid #d9d9d9; border-bottom:1px solid #d9d9d9; border-left:1px solid #d9d9d9; background-color:#efefef;" id="SR_filter_tab_4_table">

        <div style="cursor:pointer; font-family:myfont_m; font-size:12px; color:#000000; padding:7px 20px 0px 10px; background:url(img/arrow_down_1.png) right no-repeat;" onclick="F_change_SR_filter_tab(4);" onmousedown="return false;" id="SR_filter_tab_4_td">კატეგორიები</div>

    </div>


    <div class="pr-0 d-none d-sm-block" style="display: inline-block; height:30px; margin-left:0px; margin-right: 20px; top:0px; position:relative; border-top:1px solid #d9d9d9; border-right:1px solid #d9d9d9; border-bottom:1px solid #d9d9d9; border-left:1px solid #d9d9d9; background-color:#efefef;" id="SR_filter_tab_2_table">

        
<div id="SR_filter_tab_2_td" style="cursor:pointer; font-family:myfont_m; font-size:12px; color:#000000; padding:7px 20px 0px 10px; background:url(img/arrow_down_1.png) right no-repeat; white-space:nowrap;" onclick="F_change_SR_filter_tab(2);" onmousedown="return false;">
სორტირება:&nbsp;პრიორიტეტულად</div>

    </div>
<div class="col pr-0 d-none d-sm-block" style="height:30px;">
        <img class="img-fluid float-right" src="img/view_on_map.jpg" style="max-height: 30px; cursor: pointer;" onclick="F_change_to_large_map()">
    </div>



</div>

<style>
    /*es droebitaa */
.distance-1-d9{max-width: 680px;height: 0px;border-top: 1px solid #d9d9d9;overflow:hidden;}
.distance-20{height: 20px;clear: both;}
</style>
<div class="distance-1-d9"></div>

<table class="mtSR_option_willian_table3" width="679" border="0" cellpadding="0" cellspacing="10" id="SR_filter_tabres_1_table" style="display:none; border-top:0px solid #d9d9d9; border-right:1px solid #d9d9d9; border-bottom:1px solid #d9d9d9; border-left:1px solid #d9d9d9;">
<tbody><tr>
<td width="324" align="left" valign="top" bgcolor="#f3f3f3" style="border:1px solid #d9d9d9; border-radius:4px;">

<table width="322" border="0" cellpadding="0" cellspacing="0">
<tbody><tr>
<td height="32" align="left" valign="middle" colspan="3" style="font-family:myfont_m; font-size:14px; text-indent:10px; color:#005e9d;">მონაცემები</td>
</tr>



<tr>
<td height="60" align="center" valign="middle" colspan="3">

<div align="left" class="SR_filter_div_1_fal">
<div align="left" class="SR_filter_div_2_fal" style="background:transparent url(img/video_icon_2.png) 40px no-repeat; font-family:myfont_m;" onclick="F_change_SR_filter_will('SR_filter_video')">ფოტო<input name="" type="hidden" value="0" id="SR_filter_video" style="width:20px;"></div>
</div>

<div align="left" class="SR_filter_div_1_fal">
<div align="left" class="SR_filter_div_2_fal" style="background:transparent url(img/map_icon_2.png) 40px no-repeat; font-family:myfont_m;" onclick="F_change_SR_filter_will('SR_filter_map')">რუკა<input name="" type="hidden" value="0" id="SR_filter_map" style="width:20px;"></div>
</div>

<div align="left" class="SR_filter_div_1_fal">
<div align="left" class="SR_filter_div_2_fal" style="background:transparent url(img/web_icon_2.png) 40px no-repeat; font-family:myfont_m;" onclick="F_change_SR_filter_will('SR_filter_web')">ვებგვერდი<input name="" type="hidden" value="0" id="SR_filter_web" style="width:20px;"></div>
</div>

<div align="left" class="SR_filter_div_1_fal">
<div align="left" class="SR_filter_div_2_fal" style="background:transparent url(img/email_icon_2.png) 40px no-repeat; font-family:myfont_m;" onclick="F_change_SR_filter_will('SR_filter_email')">ელ-ფოსტა<input name="" type="hidden" value="0" id="SR_filter_email" style="width:20px;"></div>
</div>




<div align="left" class="SR_filter_div_1_dis">
<div align="left" class="SR_filter_div_2_dis" style="background:transparent url(img/coupon_icon_2.png) 40px no-repeat; font-family:myfont_m;">აქციები</div>
</div>

<div align="left" class="SR_filter_div_1_dis">
<div align="left" class="SR_filter_div_2_dis" style="background:transparent url(img/review_icon_2.png) 40px no-repeat; font-family:myfont_m;">მიმოხილვა</div>
</div>




</td>
</tr>















<tr style="display:none;">
<td width="32" height="25" align="center" valign="middle" style="cursor:pointer;" onclick="F_change_SR_filter('SR_filter_coupon',true)" onmouseover="F_SR_filter_over(2)" onmouseout="F_SR_filter_out(2)" id="filter_2_1"><input type="checkbox" style="cursor:pointer; outline:none;" id="SR_filter_coupon"></td>
<td width="32" height="25" align="center" valign="middle" style="cursor:pointer;" onclick="F_change_SR_filter('SR_filter_coupon',true)" onmouseover="F_SR_filter_over(2)" onmouseout="F_SR_filter_out(2)" id="filter_2_2"><img src="img/coupon_icon_2.png" width="19" height="15" style="cursor:pointer;"></td>
<td align="left" valign="middle" style="font-family:myfont_m; font-size:12px; text-indent:6px; cursor:pointer;" onclick="F_change_SR_filter('SR_filter_coupon',true)" onmouseover="F_SR_filter_over(2)" onmouseout="F_SR_filter_out(2)" id="filter_2_3">აქციები</td>
</tr>



<tr style="display:none;">
<td width="32" height="25" align="center" valign="middle" style="cursor:pointer;" onclick="F_change_SR_filter('SR_filter_menu',true)" onmouseover="F_SR_filter_over(4)" onmouseout="F_SR_filter_out(4)" id="filter_4_1"><input type="checkbox" style="cursor:pointer; outline:none;" id="SR_filter_menu"></td>
<td width="32" height="25" align="center" valign="middle" style="cursor:pointer;" onclick="F_change_SR_filter('SR_filter_menu',true)" onmouseover="F_SR_filter_over(4)" onmouseout="F_SR_filter_out(4)" id="filter_4_2"><img src="img/menu_icon_2.png" width="15" height="18" style="cursor:pointer;"></td>
<td align="left" valign="middle" style="font-family:myfont_m; font-size:12px; text-indent:6px; cursor:pointer;" onclick="F_change_SR_filter('SR_filter_menu',true)" onmouseover="F_SR_filter_over(4)" onmouseout="F_SR_filter_out(4)" id="filter_4_3">მენიუ</td>
</tr>



<tr style="display:none;">
<td width="32" height="25" align="center" valign="middle" style="cursor:pointer;" onclick="F_change_SR_filter('SR_filter_review',true)" onmouseover="F_SR_filter_over(5)" onmouseout="F_SR_filter_out(5)" id="filter_5_1"><input type="checkbox" style="cursor:pointer; outline:none;" id="SR_filter_review"></td>
<td width="32" height="25" align="center" valign="middle" style="cursor:pointer;" onclick="F_change_SR_filter('SR_filter_review',true)" onmouseover="F_SR_filter_over(5)" onmouseout="F_SR_filter_out(5)" id="filter_5_2"><img src="img/review_icon_2.png" width="15" height="14" style="cursor:pointer;"></td>
<td align="left" valign="middle" style="font-family:myfont_m; font-size:12px; text-indent:6px; cursor:pointer;" onclick="F_change_SR_filter('SR_filter_review',true)" onmouseover="F_SR_filter_over(5)" onmouseout="F_SR_filter_out(5)" id="filter_5_3">მიმოხილვა</td>
</tr>
</tbody></table>

</td>

<td width="323" align="left" valign="top" bgcolor="#f3f3f3" style="border:1px solid #d9d9d9; border-radius:4px;">

<table border="0" cellpadding="0" cellspacing="0" style=" margin:0px 7px 7px 8px; width:306px;">
<tbody><tr>
<td height="32" colspan="5" align="left" valign="middle" style="font-family:myfont_m; font-size:14px; color:#005e9d;">ალფაბეტი</td>
</tr>

<tr>

<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('0');">

ა
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('1');">

ბ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('2');">

გ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('3');">

დ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('4');">

ე
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('5');">

ვ
</td>

</tr>
<tr>

<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;">ზ</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('7');">

თ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('8');">

ი
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('9');">

კ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('10');">

ლ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('11');">

მ
</td>

</tr>
<tr>

<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('12');">

ნ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('13');">

ო
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('14');">

პ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;">ჟ</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('16');">

რ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('17');">

ს
</td>

</tr>
<tr>

<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('18');">

ტ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('19');">

უ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('20');">

ფ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('21');">

ქ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;">ღ</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;">ყ</td>

</tr>
<tr>

<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('24');">

შ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('25');">

ჩ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('26');">

ც
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;">ძ</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;">წ</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;">ჭ</td>

</tr>
<tr>

<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;">ხ</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('31');">

ჯ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('32');">

ჰ
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('33');">

#
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_letter_filter('34');">

All
</td>


<td width="51" height="24" align="center" valign="middle" style="background:url(img/SR_alps_b_1.png) left repeat-x; cursor:default; font-family:myfont_m; font-size:13px; color:#999999;"></td>

</tr>



</tbody></table>

</td>

</tr>
</tbody></table>

<table class="mtSR_option_willian_table4" width="680" border="0" cellpadding="0" cellspacing="10" id="SR_filter_tabres_2_table" style="display:none; border-top:0px solid #d9d9d9; border-right:1px solid #d9d9d9; border-bottom:1px solid #d9d9d9; border-left:1px solid #d9d9d9;">
<tbody><tr>
<td align="center" valign="top" bgcolor="#f3f3f3" style="border:1px solid #d9d9d9; border-radius:4px;">

<table border="0" cellpadding="0" cellspacing="6">
<tbody><tr>
<td width="156" height="24" align="center" valign="middle" style="background:url(img/SR_alps_bb_2.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#000000;" onclick="F_change_SR_sort('PR');">&nbsp;&nbsp;პრიორიტეტულად</td>
<td width="156" height="24" align="center" valign="middle" style="background:url(img/SR_alps_bb_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_sort('AL');">&nbsp;&nbsp;ანბანურად</td>
<td width="156" height="24" align="center" valign="middle" style="background:url(img/SR_alps_bb_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_sort('RT');">&nbsp;&nbsp;რეიტინგით</td>
<td width="156" height="24" align="center" valign="middle" style="background:url(img/SR_alps_bb_1.png) left repeat-x; cursor:pointer; font-family:myfont_m; font-size:13px; color:#005e9d;" onclick="F_change_SR_sort('RV');">&nbsp;&nbsp;რევიუ</td>
</tr>
</tbody></table>

</td>
</tr>
</tbody></table>

<table class="mtSR_option_willian_table5" width="680" border="0" cellpadding="0" cellspacing="10" id="SR_filter_tabres_3_table" style="display:none; border-top:0px solid #d9d9d9; border-right:1px solid #d9d9d9; border-bottom:1px solid #d9d9d9; border-left:1px solid #d9d9d9;">
<tbody><tr>
<td width="322" align="left" valign="top" bgcolor="#f3f3f3" style="border:1px solid #d9d9d9; border-radius:4px;"><div align="left" style="width:100%; height:32px; line-height:32px; font-family:myfont_m; font-size:14px; text-indent:10px; color:#005e9d;">ქალაქები</div>
<div style="width:100%; height:auto; max-height:175px; overflow:auto;">
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:10px; color:#000000; cursor:pointer;" onclick="F_change_region_city_from_list('თბილისი',1)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">თბილისი</div>
</div>
<div align="left" style="width:100%; height:32px; line-height:32px; font-family:myfont_m; font-size:14px; text-indent:10px; color:#005e9d;">ახლომდებარე ქალაქები</div>
<div style="width:100%; height:auto; max-height:175px; overflow:auto;">
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:10px; color:#000000; cursor:pointer;" onclick="F_change_region_city_from_list('მცხეთა',44)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">მცხეთა</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:10px; color:#000000; cursor:pointer;" onclick="F_change_region_city_from_list('რუსთავი',50)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">რუსთავი</div>
</div>
</td>
<td width="322" align="left" valign="top" bgcolor="#f3f3f3" style="border:1px solid #d9d9d9; border-radius:4px;"><div align="left" style="width:100%; height:32px; line-height:32px; font-family:myfont_m; font-size:14px; text-indent:10px; color:#005e9d;">უბნები</div>
<div style="width:100%; height:auto; max-height:175px; overflow:auto;">
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ავლაბარი, მეტრომშენი',52)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ავლაბარი, მეტრომშენი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('გლდანი',42)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">გლდანი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('დიდი დიღომი',61)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">დიდი დიღომი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('დიდუბე',46)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">დიდუბე</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('დიღომი',162)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">დიღომი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ვაზისუბანი, მე–8 ლეგიონი',54)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ვაზისუბანი, მე–8 ლეგიონი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ვაკე, ბაგები',44)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ვაკე, ბაგები</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ვარკეთილი',47)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ვარკეთილი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ვერა',25)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ვერა</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('მთაწმინდა',43)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">მთაწმინდა</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('მუხიანი',50)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">მუხიანი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ნავთლუღი, წმ. ბარბარეს უბანი(ზმკ)',105)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ნავთლუღი, წმ. ბარბარეს უბანი(ზმკ)</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ნაძალადევი',57)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ნაძალადევი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ორთაჭალა',123)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ორთაჭალა</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ორხევი, ლილო, აეროპორტი',55)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ორხევი, ლილო, აეროპორტი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('საბურთალო',62)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">საბურთალო</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('საბურთალო: დელისი, ვეძისი, ვაჟა, ნუცუბიძე',142)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">საბურთალო: დელისი, ვეძისი, ვაჟა, ნუცუბიძე</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('სოლოლაკი',53)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">სოლოლაკი</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ჩუღურეთი ქვემო',49)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ჩუღურეთი ქვემო</div>
<div align="left" style="width:100%; height:25px; line-height:25px; font-family:myfont_m; font-size:12px; text-indent:38px; color:#000000; cursor:pointer; background-color:transparent; background-image:url(img/checkbox_y_1.png); background-position:10px; background-repeat:no-repeat;" onclick="F_change_ubani_from_list('ძველი თბილისი (კალაუბანი, აბანოთუბანი)',103)" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';">ძველი თბილისი (კალაუბანი, აბანოთუბანი)</div>
</div>
</td>
</tr>
</tbody></table>

<table class="mtSR_option_willian_table6" width="680" border="0" cellpadding="0" cellspacing="10" id="SR_filter_tabres_4_table" style="display:none; border-top:0px solid #d9d9d9; border-right:1px solid #d9d9d9; border-bottom:1px solid #d9d9d9; border-left:1px solid #d9d9d9;">
<tbody><tr>
<td width="322" align="left" valign="top" bgcolor="#f3f3f3" style="border:1px solid #d9d9d9; border-radius:4px;">




<div style="width:0px; max-height:0px; position:relative; left:0px; top:0px; display:none;" id="all_categories">
</div>





<div style="width:322px; height:auto; overflow:hidden;">
<table border="0" cellpadding="0" cellspacing="0" style="width:322px;">
<tbody><tr>
<td height="32" align="left" valign="middle" style="font-family:myfont_m; font-size:14px; text-indent:10px; color:#005e9d;">კატეგორიები</td>
</tr>
<tr>
<td height="25" align="left" valign="middle" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';" onclick="F_change_cats_filter_from_list(445);" title="ტურისტული კომპანიები" style="font-family:myfont_m; font-size:12px; color:#000000; white-space:nowrap; text-indent:10px; cursor:pointer;">ტურისტული კომპანიები</td>
</tr>
</tbody></table>

</div>



</td>
<td width="322" align="left" valign="top" bgcolor="#f3f3f3" style="border:1px solid #d9d9d9; border-radius:4px;">



<div style="width:0px; max-height:0px; position:relative; left:0px; top:0px; display:none;" id="all_similar_categories">
</div>



<div style="width:322px; height:auto; overflow:hidden;">
<table border="0" cellpadding="0" cellspacing="0" style="width:322px;">
<tbody><tr>
<td height="32" align="left" valign="middle" style="font-family:myfont_m; font-size:14px; text-indent:10px; color:#005e9d;">მსგავსი კატეგორიები</td>
</tr>
<tr>
<td height="25" align="left" valign="middle" onmouseover="this.style.backgroundColor='#e5e5e5';" onmouseout="this.style.backgroundColor='transparent';" onclick="F_change_cats_filter_from_list(125);" title="ტურები, ექსკურსიები საქართველოში" style="font-family:myfont_m; font-size:12px; color:#000000; white-space:nowrap; text-indent:10px; cursor:pointer;">ტურები, ექსკურსიები საქართველოში</td>
</tr>
</tbody></table>

</div>



</td>
</tr>
</tbody></table>

<div class="distance-20 d-none d-sm-block"></div>


    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_153125">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_153125">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=153125', '_self')" onmouseover="F_SR_over_2020(153125,0);" onmouseout="F_SR_out_2020(153125,0);" id="SR_rtd_153125">


<a href="company.php?lan=geo&amp;id=153125">
<img class="img-fluid" src="logos/727.jpg" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

<!-- onClick="F_SR_p1_click(event,153125,'geo','41.709714071198','44.7853685498237',1,1,1,1,1)"-->


</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_153125">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(153125,0);" onmouseout="F_SR_out_2020(153125,0);" onclick="window.open('company.php?lan=geo&amp;id=153125', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(153125,0);" onmouseout="F_SR_out_2020(153125,0);" id="SR_ctd_153125">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=153125" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ტურისტული კომპანია ანდრო
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=153125">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=153125">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. კოსტავას ქ. 47/57</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(595) 21 03 95

</div>

<style>
    .for-text{
        max-width:479px; height:auto; margin:5px 0px 5px 0px; font-family:sylfaen; font-size:13px; line-height:16px; color:#000000; cursor:pointer;
    }
    .for-text span{cursor:pointer;}
</style>

<div align="left" class="for-text"><a href="/company.php?lan=geo&amp;id=153125" target="_blank">ავიაბილეთები ყველა მიმართულებით,&nbsp;ტურები საქართველოსა და მსოფლიოს ნებისმიერ ქვეყანაში, სასტუმროების დაჯავშნა ბახმაროში, ბათუმში, მესტიაში, ურეკში, საქართველოს სხვა ქალაქებში.</a></div>

<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">




<div style="display: inline-block;" id="SR_links_none"><a href="mailto:wuleiskiri.andro@mail.ru" target="_blank" id="SR_links_2" title="wuleiskiri.andro@mail.ru">email</a></div>



<div style="display: inline-block;" id="SR_links_none">
    <a id="SR_links_2" href="/company.php?lan=geo&amp;id=153125#PHOTOVIDEO" target="_blank">photo</a>
        
</div>



<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=153125" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_153125"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_153125">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=3792" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       მსუბუქი ავტომობილებით მომსახურება</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_153125').style.display=='none'){document.getElementById('plus_cats_div_153125').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_153125').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_153125" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    
<div style="max-width:676px; z-index:10; margin-right: 10px;">
<a href="/company.php?lan=geo&amp;id=153125" target="_blank" style="padding:0px 13px 0px 0px; right:10px; top:5px; cursor:pointer; background-image:url(img/sr_info_c_arrow.png); 
   background-position:right; background-repeat:no-repeat; font-family:sylfaen; font-size:12px; color:#005e9d;" id="SR_oc1_153125">მეტი</a>
</div>

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_153125"></div>








    </div>
    
</div>















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_109192">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_109192">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=109192', '_self')" onmouseover="F_SR_over_2020(109192,0);" onmouseout="F_SR_out_2020(109192,0);" id="SR_rtd_109192">


<a href="company.php?lan=geo&amp;id=109192">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:default;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_109192">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(109192,0);" onmouseout="F_SR_out_2020(109192,0);" onclick="window.open('company.php?lan=geo&amp;id=109192', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(109192,0);" onmouseout="F_SR_out_2020(109192,0);" id="SR_ctd_109192">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=109192" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

სან ექსპრესი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


<a href="company.php?lan=geo&amp;id=109192">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი.  </span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(555) 333 171

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.sunexpress.ge" target="_blank" id="SR_links_2" title="http://www.sunexpress.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info.sunexpress@gmail.com" target="_blank" id="SR_links_2" title="info.sunexpress@gmail.com">email</a></div>






<div style="display:none;">menu</div>

  
    



<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_109192"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_109192">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_109192').style.display=='none'){document.getElementById('plus_cats_div_109192').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_109192').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_109192" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_109192"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_146031">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_146031">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=146031', '_self')" onmouseover="F_SR_over_2020(146031,0);" onmouseout="F_SR_out_2020(146031,0);" id="SR_rtd_146031">


<a href="company.php?lan=geo&amp;id=146031">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_146031">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(146031,0);" onmouseout="F_SR_out_2020(146031,0);" onclick="window.open('company.php?lan=geo&amp;id=146031', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(146031,0);" onmouseout="F_SR_out_2020(146031,0);" id="SR_ctd_146031">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=146031" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

თრეველგეითი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=146031">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=146031">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. მაზნიაშვილის ქ. 17</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
242 25 22,&nbsp;&nbsp;&nbsp;(577) 08 25 25

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://travelgate.ge" target="_blank" id="SR_links_2" title="http://travelgate.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@travelgate.ge" target="_blank" id="SR_links_2" title="info@travelgate.ge">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=146031" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_146031"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_146031">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_146031').style.display=='none'){document.getElementById('plus_cats_div_146031').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_146031').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_146031" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_146031"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_140044">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_140044">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=140044', '_self')" onmouseover="F_SR_over_2020(140044,0);" onmouseout="F_SR_out_2020(140044,0);" id="SR_rtd_140044">


<a href="company.php?lan=geo&amp;id=140044">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_140044">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(140044,0);" onmouseout="F_SR_out_2020(140044,0);" onclick="window.open('company.php?lan=geo&amp;id=140044', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(140044,0);" onmouseout="F_SR_out_2020(140044,0);" id="SR_ctd_140044">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=140044" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ჰეფი თრეველ ჯორჯია
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=140044">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=140044">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ჯანაშიას ქ. 28</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(555) 24 73 73,&nbsp;&nbsp;&nbsp; 

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.happytravel.ge" target="_blank" id="SR_links_2" title="http://www.happytravel.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@happytravel.ge" target="_blank" id="SR_links_2" title="info@happytravel.ge">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=140044" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_140044"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_140044">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_140044').style.display=='none'){document.getElementById('plus_cats_div_140044').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_140044').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_140044" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_140044"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_132666">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_132666">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=132666', '_self')" onmouseover="F_SR_over_2020(132666,0);" onmouseout="F_SR_out_2020(132666,0);" id="SR_rtd_132666">


<a href="company.php?lan=geo&amp;id=132666">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_132666">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(132666,0);" onmouseout="F_SR_out_2020(132666,0);" onclick="window.open('company.php?lan=geo&amp;id=132666', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(132666,0);" onmouseout="F_SR_out_2020(132666,0);" id="SR_ctd_132666">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=132666" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

არბიეს თრეველი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=132666">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=132666">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ფალიაშვილის ქ. 118, ბ. 12</span>
</a>
    


<a href="/company.php?lan=geo&amp;id=132666" target="_blank" id="SR_links_2" style="cursor:pointer; padding:2px 6px 2px 0px; font-family:sylfaen; font-size:12px; color:#333333; background-color:transparent; background-image:url(img/branch_more_bg.png); background-position:0px 0px; background-repeat:no-repeat;" onmouseover="this.style.backgroundPosition='0px -20px';this.style.color='#FFFFFF';" onmouseout="this.style.backgroundPosition='0px 0px';this.style.color='#333333';">
    &nbsp;&nbsp;&nbsp;+2&nbsp;მისამართი</a>


<!--<a style="width:auto; height:auto; margin:6px 0px 0px 0px; font-family:sylfaen; font-size:13px; color:#d93300; cursor:pointer; background:url(img/plus_cats_red.gif) left no-repeat; padding-left:14px; margin-left:10px;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_SR_branch_click(132666,'geo')">ყველა მისამართი</a>-->

</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
249 65 75,&nbsp;&nbsp;&nbsp;(591) 04 04 11

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.rbs-travels.com" target="_blank" id="SR_links_2" title="http://www.rbs-travels.com">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info.rbstravel@gmail.com" target="_blank" id="SR_links_2" title="info.rbstravel@gmail.com">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=132666" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_132666"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_132666">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_132666').style.display=='none'){document.getElementById('plus_cats_div_132666').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_132666').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_132666" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_132666"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_108205">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_108205">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=108205', '_self')" onmouseover="F_SR_over_2020(108205,0);" onmouseout="F_SR_out_2020(108205,0);" id="SR_rtd_108205">


<a href="company.php?lan=geo&amp;id=108205">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_108205">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(108205,0);" onmouseout="F_SR_out_2020(108205,0);" onclick="window.open('company.php?lan=geo&amp;id=108205', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(108205,0);" onmouseout="F_SR_out_2020(108205,0);" id="SR_ctd_108205">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=108205" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

სქაი თრეველი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=108205">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=108205">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ყაზბეგის გამზ. 7</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
291 04 71,&nbsp;&nbsp;&nbsp;231 32 20

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.facebook.com/skytravelgeorgia" target="_blank" id="SR_links_2" title="http://www.facebook.com/skytravelgeorgia">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:sky-travel2012@hotmail.com" target="_blank" id="SR_links_2" title="sky-travel2012@hotmail.com">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=108205" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_108205"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_108205">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_108205').style.display=='none'){document.getElementById('plus_cats_div_108205').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_108205').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_108205" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_108205"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_67797">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_67797">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=67797', '_self')" onmouseover="F_SR_over_2020(67797,0);" onmouseout="F_SR_out_2020(67797,0);" id="SR_rtd_67797">


<a href="company.php?lan=geo&amp;id=67797">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_67797">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(67797,0);" onmouseout="F_SR_out_2020(67797,0);" onclick="window.open('company.php?lan=geo&amp;id=67797', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(67797,0);" onmouseout="F_SR_out_2020(67797,0);" id="SR_ctd_67797">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=67797" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

კლარკ &amp; რობინსონი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=67797">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=67797">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. კეკელიძის ქ. 7</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
222 12 24,&nbsp;&nbsp;&nbsp;222 12 25,&nbsp;&nbsp;&nbsp;<div class="tel_div"></div>222 12 85

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.clarkrobinsson.ge" target="_blank" id="SR_links_2" title="http://www.clarkrobinsson.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:tamriko@clarkrobinsson.ge" target="_blank" id="SR_links_2" title="tamriko@clarkrobinsson.ge">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=67797" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_67797"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_67797">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_67797').style.display=='none'){document.getElementById('plus_cats_div_67797').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_67797').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_67797" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_67797"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_155274">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_155274">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=155274', '_self')" onmouseover="F_SR_over_2020(155274,0);" onmouseout="F_SR_out_2020(155274,0);" id="SR_rtd_155274">


<a href="company.php?lan=geo&amp;id=155274">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:default;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_155274">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(155274,0);" onmouseout="F_SR_out_2020(155274,0);" onclick="window.open('company.php?lan=geo&amp;id=155274', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(155274,0);" onmouseout="F_SR_out_2020(155274,0);" id="SR_ctd_155274">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=155274" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

დაკი თრეველ
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


<a href="company.php?lan=geo&amp;id=155274">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ც. დადიანის ქ. 7, სავაჭრო ცენტრი "ქარვასლა", სართ. 3, ოფ. B309</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(511) 260 260

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="https://www.dakitravel.com" target="_blank" id="SR_links_2" title="https://www.dakitravel.com">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:dakitravel2022@gmail.com; office@dakitravel.com" target="_blank" id="SR_links_2" title="dakitravel2022@gmail.com; office@dakitravel.com">email</a></div>






<div style="display:none;">menu</div>

  
    



<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_155274"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_155274">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_155274').style.display=='none'){document.getElementById('plus_cats_div_155274').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_155274').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_155274" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_155274"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_76824">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_76824">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=76824', '_self')" onmouseover="F_SR_over_2020(76824,0);" onmouseout="F_SR_out_2020(76824,0);" id="SR_rtd_76824">


<a href="company.php?lan=geo&amp;id=76824">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_76824">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(76824,0);" onmouseout="F_SR_out_2020(76824,0);" onclick="window.open('company.php?lan=geo&amp;id=76824', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(76824,0);" onmouseout="F_SR_out_2020(76824,0);" id="SR_ctd_76824">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=76824" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ანსონი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=76824">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=76824">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. რუსთაველის გამზ. 14</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
293 32 70,&nbsp;&nbsp;&nbsp;(599) 56 76 00

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.ansoni.com.ge" target="_blank" id="SR_links_2" title="http://www.ansoni.com.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:vovashen@yahoo.com" target="_blank" id="SR_links_2" title="vovashen@yahoo.com">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=76824" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_76824"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_76824">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_76824').style.display=='none'){document.getElementById('plus_cats_div_76824').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_76824').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_76824" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_76824"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_131476">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_131476">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=131476', '_self')" onmouseover="F_SR_over_2020(131476,0);" onmouseout="F_SR_out_2020(131476,0);" id="SR_rtd_131476">


<a href="company.php?lan=geo&amp;id=131476">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_131476">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(131476,0);" onmouseout="F_SR_out_2020(131476,0);" onclick="window.open('company.php?lan=geo&amp;id=131476', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(131476,0);" onmouseout="F_SR_out_2020(131476,0);" id="SR_ctd_131476">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=131476" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

აჭარა ტური
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=131476">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=131476">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ჭავჭავაძის გამზ. 16</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
+995 593 87 87 78

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.adjaratour.com" target="_blank" id="SR_links_2" title="http://www.adjaratour.com">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:tbilisi@adjaratour.com" target="_blank" id="SR_links_2" title="tbilisi@adjaratour.com">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=131476" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_131476"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>







<div style="background-color:#0099FF; width:0px; height:0px; display:none;" id="plus_cats_div_131476">
<div style="background-color:#9900FF; width:0px; height:0px;" id="plus_cats_div_icon_131476"></div>
</div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_131476"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_145967">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_145967">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=145967', '_self')" onmouseover="F_SR_over_2020(145967,0);" onmouseout="F_SR_out_2020(145967,0);" id="SR_rtd_145967">


<a href="company.php?lan=geo&amp;id=145967">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:default;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_145967">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(145967,0);" onmouseout="F_SR_out_2020(145967,0);" onclick="window.open('company.php?lan=geo&amp;id=145967', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(145967,0);" onmouseout="F_SR_out_2020(145967,0);" id="SR_ctd_145967">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=145967" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ლუკას თრეველი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


<a href="company.php?lan=geo&amp;id=145967">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. კუპრაძის ქ. 72</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(558) 75 57 27

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.lukastravel.ge" target="_blank" id="SR_links_2" title="http://www.lukastravel.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:lukastravel.georgia@gmail.com" target="_blank" id="SR_links_2" title="lukastravel.georgia@gmail.com">email</a></div>






<div style="display:none;">menu</div>

  
    



<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_145967"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_145967">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_145967').style.display=='none'){document.getElementById('plus_cats_div_145967').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_145967').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_145967" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_145967"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_136124">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_136124">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=136124', '_self')" onmouseover="F_SR_over_2020(136124,0);" onmouseout="F_SR_out_2020(136124,0);" id="SR_rtd_136124">


<a href="company.php?lan=geo&amp;id=136124">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:default;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_136124">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(136124,0);" onmouseout="F_SR_out_2020(136124,0);" onclick="window.open('company.php?lan=geo&amp;id=136124', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(136124,0);" onmouseout="F_SR_out_2020(136124,0);" id="SR_ctd_136124">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=136124" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

მანგო თრეველი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


<a href="company.php?lan=geo&amp;id=136124">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ხეთაგუროვის ქ. 4</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(579) 90 15 16

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.mangotravel.ge" target="_blank" id="SR_links_2" title="http://www.mangotravel.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:mangotravel@yahoo.com" target="_blank" id="SR_links_2" title="mangotravel@yahoo.com">email</a></div>






<div style="display:none;">menu</div>

  
    



<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_136124"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_136124">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_136124').style.display=='none'){document.getElementById('plus_cats_div_136124').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_136124').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_136124" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_136124"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_107837">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_107837">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=107837', '_self')" onmouseover="F_SR_over_2020(107837,0);" onmouseout="F_SR_out_2020(107837,0);" id="SR_rtd_107837">


<a href="company.php?lan=geo&amp;id=107837">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_107837">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(107837,0);" onmouseout="F_SR_out_2020(107837,0);" onclick="window.open('company.php?lan=geo&amp;id=107837', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(107837,0);" onmouseout="F_SR_out_2020(107837,0);" id="SR_ctd_107837">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=107837" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

გლობალ თრეველი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=107837">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=107837">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. კანდელაკის ქ. 33</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
223 18 33

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.globaltravel.ge" target="_blank" id="SR_links_2" title="http://www.globaltravel.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@globaltravel.ge" target="_blank" id="SR_links_2" title="info@globaltravel.ge">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=107837" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_107837"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_107837">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_107837').style.display=='none'){document.getElementById('plus_cats_div_107837').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_107837').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_107837" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_107837"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_101421">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_101421">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=101421', '_self')" onmouseover="F_SR_over_2020(101421,0);" onmouseout="F_SR_out_2020(101421,0);" id="SR_rtd_101421">


<a href="company.php?lan=geo&amp;id=101421">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:default;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_101421">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(101421,0);" onmouseout="F_SR_out_2020(101421,0);" onclick="window.open('company.php?lan=geo&amp;id=101421', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(101421,0);" onmouseout="F_SR_out_2020(101421,0);" id="SR_ctd_101421">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=101421" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

სითი ტური
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


<a href="company.php?lan=geo&amp;id=101421">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. თამარაშვილის ქ. 3</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(599) 18 85 15

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.citytour.ge" target="_blank" id="SR_links_2" title="http://www.citytour.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@citytour.ge" target="_blank" id="SR_links_2" title="info@citytour.ge">email</a></div>






<div style="display:none;">menu</div>

  
    



<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_101421"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_101421">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_101421').style.display=='none'){document.getElementById('plus_cats_div_101421').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_101421').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_101421" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_101421"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_104418">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_104418">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=104418', '_self')" onmouseover="F_SR_over_2020(104418,0);" onmouseout="F_SR_out_2020(104418,0);" id="SR_rtd_104418">


<a href="company.php?lan=geo&amp;id=104418">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:default;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_104418">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(104418,0);" onmouseout="F_SR_out_2020(104418,0);" onclick="window.open('company.php?lan=geo&amp;id=104418', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(104418,0);" onmouseout="F_SR_out_2020(104418,0);" id="SR_ctd_104418">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=104418" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ბი თი ელი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


<a href="company.php?lan=geo&amp;id=104418">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი.  </span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(568) 519 519,&nbsp;&nbsp;&nbsp;(599) 55 51 98

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.btl-company.ge" target="_blank" id="SR_links_2" title="http://www.btl-company.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:georgia@btl-company.com" target="_blank" id="SR_links_2" title="georgia@btl-company.com">email</a></div>






<div style="display:none;">menu</div>

  
    



<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_104418"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_104418">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_104418').style.display=='none'){document.getElementById('plus_cats_div_104418').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_104418').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_104418" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_104418"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_120764">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_120764">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=120764', '_self')" onmouseover="F_SR_over_2020(120764,0);" onmouseout="F_SR_out_2020(120764,0);" id="SR_rtd_120764">


<a href="company.php?lan=geo&amp;id=120764">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_120764">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(120764,0);" onmouseout="F_SR_out_2020(120764,0);" onclick="window.open('company.php?lan=geo&amp;id=120764', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(120764,0);" onmouseout="F_SR_out_2020(120764,0);" id="SR_ctd_120764">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=120764" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ვი ეს თი ტურები და ბილეთები, ვი ეს თი ჯორჯია
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=120764">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=120764">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. რკინის რიგი 11 / კოტე აფხაზის ქ. 44</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
243 88 08,&nbsp;&nbsp;&nbsp;(514) 21 77 22,&nbsp;&nbsp;&nbsp;<div class="tel_div"></div>(579) 20 50 50 

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.wst.ge" target="_blank" id="SR_links_2" title="http://www.wst.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@wst.ge" target="_blank" id="SR_links_2" title="info@wst.ge">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=120764" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_120764"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_120764">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_120764').style.display=='none'){document.getElementById('plus_cats_div_120764').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_120764').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_120764" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_120764"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_75910">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_75910">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=75910', '_self')" onmouseover="F_SR_over_2020(75910,0);" onmouseout="F_SR_out_2020(75910,0);" id="SR_rtd_75910">


<a href="company.php?lan=geo&amp;id=75910">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_75910">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(75910,0);" onmouseout="F_SR_out_2020(75910,0);" onclick="window.open('company.php?lan=geo&amp;id=75910', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(75910,0);" onmouseout="F_SR_out_2020(75910,0);" id="SR_ctd_75910">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=75910" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

პროფკურორტი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=75910">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=75910">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ვაჟა-ფშაველას I შესახვ. 1/43</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(599) 145 168,&nbsp;&nbsp;&nbsp;(592) 10 27 72

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.profkurort.ge" target="_blank" id="SR_links_2" title="http://www.profkurort.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:travel@profkurort.ge" target="_blank" id="SR_links_2" title="travel@profkurort.ge">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=75910" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_75910"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_75910">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_75910').style.display=='none'){document.getElementById('plus_cats_div_75910').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_75910').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_75910" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_75910"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_67133">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_67133">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=67133', '_self')" onmouseover="F_SR_over_2020(67133,0);" onmouseout="F_SR_out_2020(67133,0);" id="SR_rtd_67133">


<a href="company.php?lan=geo&amp;id=67133">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_67133">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(67133,0);" onmouseout="F_SR_out_2020(67133,0);" onclick="window.open('company.php?lan=geo&amp;id=67133', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(67133,0);" onmouseout="F_SR_out_2020(67133,0);" id="SR_ctd_67133">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=67133" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

პლანეტა თრეველი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=67133">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=67133">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. აღმაშენებლის გამზ. 183</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
235 55 19,&nbsp;&nbsp;&nbsp;(574) 80 11 12

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.planetatravel.ge" target="_blank" id="SR_links_2" title="http://www.planetatravel.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:muradmimino@mail.ru" target="_blank" id="SR_links_2" title="muradmimino@mail.ru">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=67133" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_67133"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_67133">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_67133').style.display=='none'){document.getElementById('plus_cats_div_67133').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_67133').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_67133" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_67133"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_79040">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_79040">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=79040', '_self')" onmouseover="F_SR_over_2020(79040,0);" onmouseout="F_SR_out_2020(79040,0);" id="SR_rtd_79040">


<a href="company.php?lan=geo&amp;id=79040">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_79040">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(79040,0);" onmouseout="F_SR_out_2020(79040,0);" onclick="window.open('company.php?lan=geo&amp;id=79040', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(79040,0);" onmouseout="F_SR_out_2020(79040,0);" id="SR_ctd_79040">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=79040" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

საქართველოს საპატრიარქოს რელიგიური ტურიზმის დეპარტამენტი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=79040">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=79040">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ერეკლე II მოედ. 1</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(577) 44 30 10,&nbsp;&nbsp;&nbsp;292 39 78

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="https://www.facebook.com/საპატრიარქოს-რელიგიური-ტურიზმის-დეპარტამენტი-664107927067985" target="_blank" id="SR_links_2" title="https://www.facebook.com/საპატრიარქოს-რელიგიური-ტურიზმის-დეპარტამენტი-664107927067985">website</a></div>








<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=79040" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_79040"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_79040">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=288" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       რელიგიური ორგანიზაციები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_79040').style.display=='none'){document.getElementById('plus_cats_div_79040').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_79040').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_79040" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_79040"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_78210">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_78210">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=78210', '_self')" onmouseover="F_SR_over_2020(78210,0);" onmouseout="F_SR_out_2020(78210,0);" id="SR_rtd_78210">


<a href="company.php?lan=geo&amp;id=78210">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_78210">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(78210,0);" onmouseout="F_SR_out_2020(78210,0);" onclick="window.open('company.php?lan=geo&amp;id=78210', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(78210,0);" onmouseout="F_SR_out_2020(78210,0);" id="SR_ctd_78210">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=78210" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ავიასალარო 24
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=78210">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=78210">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ჭავჭავაძის გამზ. 2</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(599) 526 007,&nbsp;&nbsp;&nbsp;(595) 64 15 25 

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.aviabiletebi24.ge" target="_blank" id="SR_links_2" title="http://www.aviabiletebi24.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@aviabiletebi24.ge" target="_blank" id="SR_links_2" title="info@aviabiletebi24.ge">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=78210" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_78210"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_78210">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_78210').style.display=='none'){document.getElementById('plus_cats_div_78210').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_78210').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_78210" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_78210"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_128905">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_128905">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=128905', '_self')" onmouseover="F_SR_over_2020(128905,0);" onmouseout="F_SR_out_2020(128905,0);" id="SR_rtd_128905">


<a href="company.php?lan=geo&amp;id=128905">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:default;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_128905">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(128905,0);" onmouseout="F_SR_out_2020(128905,0);" onclick="window.open('company.php?lan=geo&amp;id=128905', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(128905,0);" onmouseout="F_SR_out_2020(128905,0);" id="SR_ctd_128905">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=128905" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ბლუ ბირდ თრეველ
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


<a href="company.php?lan=geo&amp;id=128905">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ბესიკის ქ. 4, ბიზნეს-ცენტრი "ბესიკი"</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(599) 17 71 02,&nbsp;&nbsp;&nbsp;(599) 19 00 22

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.bluebirdtravel.ge" target="_blank" id="SR_links_2" title="http://www.bluebirdtravel.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@bluebirdtravel.ge" target="_blank" id="SR_links_2" title="info@bluebirdtravel.ge">email</a></div>






<div style="display:none;">menu</div>

  
    



<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_128905"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>







<div style="background-color:#0099FF; width:0px; height:0px; display:none;" id="plus_cats_div_128905">
<div style="background-color:#9900FF; width:0px; height:0px;" id="plus_cats_div_icon_128905"></div>
</div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_128905"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_145831">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_145831">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=145831', '_self')" onmouseover="F_SR_over_2020(145831,0);" onmouseout="F_SR_out_2020(145831,0);" id="SR_rtd_145831">


<a href="company.php?lan=geo&amp;id=145831">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_145831">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(145831,0);" onmouseout="F_SR_out_2020(145831,0);" onclick="window.open('company.php?lan=geo&amp;id=145831', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(145831,0);" onmouseout="F_SR_out_2020(145831,0);" id="SR_ctd_145831">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=145831" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

დაივერს ჯორჯია
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=145831">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=145831">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. წერეთლის გამზ. 116, "დიდუბე პლაზა"</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(599) 20 99 44,&nbsp;&nbsp;&nbsp;(599) 02 44 66 

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.diversegeorgia.com" target="_blank" id="SR_links_2" title="http://www.diversegeorgia.com">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@diversegeorgia.com" target="_blank" id="SR_links_2" title="info@diversegeorgia.com">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=145831" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_145831"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_145831">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_145831').style.display=='none'){document.getElementById('plus_cats_div_145831').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_145831').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_145831" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_145831"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_67446">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_67446">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=67446', '_self')" onmouseover="F_SR_over_2020(67446,0);" onmouseout="F_SR_out_2020(67446,0);" id="SR_rtd_67446">


<a href="company.php?lan=geo&amp;id=67446">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_67446">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(67446,0);" onmouseout="F_SR_out_2020(67446,0);" onclick="window.open('company.php?lan=geo&amp;id=67446', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(67446,0);" onmouseout="F_SR_out_2020(67446,0);" id="SR_ctd_67446">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=67446" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

ანტალია სერვისი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=67446">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=67446">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. პუშკინის ქ. 10</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
(599) 14 20 60,&nbsp;&nbsp;&nbsp;(577) 49 36 16

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.facebook.com/ANTALYA-SERVICE-322003574876" target="_blank" id="SR_links_2" title="http://www.facebook.com/ANTALYA-SERVICE-322003574876">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:antaliaser@hotmail.com" target="_blank" id="SR_links_2" title="antaliaser@hotmail.com">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=67446" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_67446"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_67446">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_67446').style.display=='none'){document.getElementById('plus_cats_div_67446').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_67446').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_67446" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_67446"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_80278">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_80278">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=80278', '_self')" onmouseover="F_SR_over_2020(80278,0);" onmouseout="F_SR_out_2020(80278,0);" id="SR_rtd_80278">


<a href="company.php?lan=geo&amp;id=80278">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_80278">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(80278,0);" onmouseout="F_SR_out_2020(80278,0);" onclick="window.open('company.php?lan=geo&amp;id=80278', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(80278,0);" onmouseout="F_SR_out_2020(80278,0);" id="SR_ctd_80278">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=80278" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

კერა თრეველი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:80px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(1 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=80278">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=80278">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. ფალიაშვილის ქ. 63</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
238 97 98,&nbsp;&nbsp;&nbsp;242 50 40

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.keratravel.com" target="_blank" id="SR_links_2" title="http://www.keratravel.com">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@keratravel.com" target="_blank" id="SR_links_2" title="info@keratravel.com">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=80278" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_80278"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_80278">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_80278').style.display=='none'){document.getElementById('plus_cats_div_80278').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_80278').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_80278" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_80278"></div>








    </div>
    
</div>
 















    
    




<div class="container px-0 pt-0 pb-3" style=" ; max-width:680px; height:auto; border:1px solid #CECECE;margin:0px 0px 10px 0px; " id="SR_div_108923">

<div class="row p-0 m-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_108923">
<!--111111111111111111111111-->
<div class="col-3 pt-2 pl-2" style="max-width: 152px; cursor: pointer;" onclick="window.open('company.php?lan=geo&amp;id=108923', '_self')" onmouseover="F_SR_over_2020(108923,0);" onmouseout="F_SR_out_2020(108923,0);" id="SR_rtd_108923">


<a href="company.php?lan=geo&amp;id=108923">
<img class="img-fluid" src="img/logo_default.png" style="margin:6px 10px 0px 0px; border:0px solid #cecece; cursor:pointer;">
</a>

</div>

<div class="col-9 pl-0 ml-0" style="border:1px solid #FFFFFF; background-color:#FFFFFF;" id="SR_table_108923">

<!-- 2222222222222222222222222 -->
<div style="width:10px;cursor: pointer;" onmouseover="F_SR_over_2020(108923,0);" onmouseout="F_SR_out_2020(108923,0);" onclick="window.open('company.php?lan=geo&amp;id=108923', '_self')">
</div>
<!--33333333333333333333333-->
<div align="left" valign="top" style="max-width: 489px; cursor: default; " onmouseover="F_SR_over_2020(108923,0);" onmouseout="F_SR_out_2020(108923,0);" id="SR_ctd_108923">
    
    <!--Name-->
<div style="max-width:479px; height:auto; margin:15px 0px 0px 0px; font-family:myfont_m; font-size:15px; font-weight:bold; 
     color:#114b8c; cursor:default; ">

<a href="company.php?lan=geo&amp;id=108923" style="font-family:myfont_m; font-size:17px; font-weight:normal; color:#114b8c; cursor:pointer; " onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';">

გუდ თრეველი
</a>
</div>


<!--rating and review-->
<div style="display: inline-block; width:80px; height:16px; overflow:hidden; position:relative; left:0px; top:0px; background-color:#C0C0C0;">
<div style="width:0px; height:16px; overflow:hidden; position:absolute; left:0px; top:0px; background-color:#FFD400;"></div>
<img src="img/stars_alpha.png" width="80" height="16" alt="" style="position:absolute; left:0px;">
</div>




<div style="display: inline-block; vertical-align: top; cursor:default; font-family:Tahoma; font-size:12px; letter-spacing:1px; font-weight:normal; color:#999999;">

(0 <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">
    რეიტინგი</span> | 0 
    <span style="cursor:default;font-family:sylfaen; letter-spacing:-0.1px;">რევიუ</span>)
   
</div>
<!--misamarti-->
<div align="left" style="max-width:479px; height:auto; margin:1px 0px 0px 0px;">

<div style="font-family:sylfaen;font-size:14px;color:#000000;">


    <span>
        <a href="company.php?lan=geo&amp;id=108923">
            <img src="img/marker_map.png" style="cursor:pointer;width:15px;height:auto;position:relative;top:1px;margin-right:3px;">
        </a>
    </span>
    <a href="company.php?lan=geo&amp;id=108923">
    <span style="cursor:pointer;font-size:14px;color:#000000; ">თბილისი. მელიქიშვილის ქ. 17</span>
</a>
    


</div>


</div>

<style>
    .tel_div{display: none;}
    
    @media screen and (max-width: 450px) {
        .tel_font_companies{font-size: 15px!important;font-weight: 500!important;}
        .tel_div{display: block;}
    }
    
 
</style>


<div class="tel_font_companies" style="cursor:default; height:auto; margin:5px 0px 0px 0px; font-family:arial; font-size:13px; font-weight:bold; color:#333333;">



<!--<span style="font-family:myfont_m; font-size:14px; font-weight:bold; color:#333333;">ტელ:</span>-->
2 300 700,&nbsp;&nbsp;&nbsp;(555) 912 139,&nbsp;&nbsp;&nbsp;<div class="tel_div"></div>(557) 078 282

</div>


<div align="left" style="max-width:479px; height:auto; margin:2px 0px 4px 0px; padding:0px 0px 0px 0px;">


<div style="display: inline-block;" id="SR_links_none">
    <a href="http://www.goodtravel.ge" target="_blank" id="SR_links_2" title="http://www.goodtravel.ge">website</a></div>


<div style="display: inline-block;" id="SR_links_none"><a href="mailto:info@goodtravel.ge" target="_blank" id="SR_links_2" title="info@goodtravel.ge">email</a></div>






<div style="display:none;">menu</div>

  
    <div style="display: inline-block;" id="SR_links_none">
    <a href="/company.php?lan=geo&amp;id=108923" target="_blank" id="SR_links_2">map</a></div>




<div style="display: inline-block" id="SR_links_none">
    <div id="add_to_book_108923"><span style="font-family:Arial; font-size:12px; cursor:pointer; color:#114B8D; padding-left:12px; background:url(img/bloknot_gray.png) left no-repeat;" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" onclick="F_alert('alert_register_to_add','info');">bloknot</span></div>
</div>

  
    


</div>



<div style="width:0px; height:0px; position:relative; left:0px; top:0px; z-index:1000; display:none;" id="alert_register_to_add">
იმისათვის, რომ შეძლოთ კომპანიის "ბლოკნოტში" დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>



<div style="max-width:479px; line-height:17px; margin-bottom:1px;">


<!--<span style="font-family:sylfaen; font-size:12px;">კატეგორიები:</span>-->





<a href="companies.php?lan=geo&amp;rub=445" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურისტული კომპანიები</a>





<span style="display:none;" id="plus_cats_div_108923">


<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=6" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ავიაბილეთები</a>








<span style="font-family:Arial; font-size:10px; color:#114B8C; font-weight:normal;"> &nbsp; | &nbsp; </span><a href="companies.php?lan=geo&amp;rub=125" onmouseover="this.style.textDecoration='underline';" onmouseout="this.style.textDecoration='none';" style=" font-family:sylfaen; font-size:12px; color:#114b8c; cursor:pointer; letter-spacing:0px;">
       ტურები, ექსკურსიები საქართველოში</a>







</span>
    <div style="display: inline-block; margin-top: 6px; align: left;"><a style="background:url(img/plus_cats.gif) left no-repeat; font-family:Sylfaen; font-size:12px; color:#006600; padding:0px 0px 0px 0px;" onclick="if(document.getElementById('plus_cats_div_108923').style.display=='none'){document.getElementById('plus_cats_div_108923').style.display='';this.style.backgroundImage='url(img/plus_cats_2.gif)';}else{document.getElementById('plus_cats_div_108923').style.display='none';this.style.backgroundImage='url(img/plus_cats.gif)';}" id="plus_cats_div_icon_108923" title="იხილეთ ყველა კატეგორია">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ყველა&nbsp;კატეგორიის&nbsp;ნახვა</a>
    </div>


</div>






</div>
</div>

</div> 
    <!--4444444444-->
    
    <div class="d-flex flex-row-reverse">
    

<div align="left" style="height:0px; width:100%; position:relative; left:0px; top:0px; background-color:#EEEEEE; opacity:0; filter:alpha(opacity=0); display:block;" id="SR_b_p_108923"></div>








    </div>
    
</div>
 



















<div style="max-width:680px; height:0px; border-top:1px solid #CECECE;"></div>

<div style="max-width: 680px; max-height: 52px; margin-bottom: 10px; background-color: #f8f8f8">
<div style="display: inline-block;">

<div style="display: inline-block; width: 22px; height: 20px;" align="center" valign="middle"><img src="img/S_res_pg_l_0.png"></div>





<div style="display: inline-block; width: 20px; height: 20px; margin-right: 3px;" align="center" valign="middle" id="S_res_pg2">1</div>


<div style="display: inline-block; width: 20px; height: 20px; margin-right: 3px;" align="center" valign="middle" onclick="F_change_SR_pg(2)" id="S_res_pg1">2</div>


<div style="display: inline-block; width: 20px; height: 20px; margin-right: 3px;" align="center" valign="middle" onclick="F_change_SR_pg(3)" id="S_res_pg1">3</div>


<div style="display: inline-block; width: 20px; height: 20px; margin-right: 3px;" align="center" valign="middle" onclick="F_change_SR_pg(4)" id="S_res_pg1">4</div>


<div style="display: inline-block; width: 20px; height: 20px; margin-right: 3px;" align="center" valign="middle" onclick="F_change_SR_pg(5)" id="S_res_pg1">5</div>


<div style="display: inline-block; width: 18px; height: 20px;" align="center" valign="middle" id="S_res_pg3">...</div>

<div style="display: inline-block; width: 22px; height: 20px;" align="center" valign="middle"><img src="img/S_res_pg_r_1.png" onmouseover="this.src='img/S_res_pg_r_2.png'" onmouseout="this.src='img/S_res_pg_r_1.png'" onclick="F_change_SR_pg(2)" style="cursor:pointer; display: inline-block;"></div>


</div>

<div style="display: inline-block; float: right; margin-left: 10px;" align="right" valign="middle">

<span style="font-family:Sylfaen; font-size:12px; color:#005e9d;">გვერდი: </span>

<span style="font-family:Tahoma; font-size:12px; color:#005e9d; margin-right:10px;">
1 (8)</span>

</div>

</div>

    </div>
     
        
   </div>
</div>






































<div class="container-fluid footer-table" style="background-color: #EAEAEA;" id="footer">
    <div class="container p-0" style="max-width: 960px; height:auto; background-color: #EAEAEA">
    <div class="row mx-0 px-0" style="max-width: 960px; height:auto; background-color: #EAEAEA">
        <div class="col-md-3 col-sm-5 px-0">


<div style="margin-top: 5px; padding:2px 3px 2px 0px;"><img src="ada/img/foot_logo.png" alt="" width="120" border="0" onmousedown="return false;"></div>

        </div>
        <div class="col-md-9 col-sm-5 px-0">
            
<div class="row d-none d-md-block" style="padding:2px 0px 2px 0px;"><a href="http://yell.ge/add_company.php" style="font-family:myfont_m; font-size:12px; font-weight:bold; color:#333333;">დაამატეთ&nbsp;კომპანია</a> &nbsp;&nbsp; <span style="font-size:12px;">|</span> &nbsp;&nbsp; 
<a href="http://yell.ge/ada/onlo.php" style="font-family:myfont_m; font-size:12px; font-weight:bold; color:#333333;">რეკლამა</a> &nbsp;&nbsp; <span style="font-size:12px;">|</span> &nbsp;&nbsp; 
<a href="http://yell.ge/about_us.php" style="font-family:myfont_m; font-size:12px; font-weight:bold; color:#333333;">ჩვენს&nbsp;შესახებ</a> &nbsp;&nbsp; <span style="font-size:12px;">|</span> &nbsp;&nbsp; 
<a href="http://yell.ge/contact.php" style="font-family:myfont_m; font-size:12px; font-weight:bold; color:#333333;">კონტაქტი</a> &nbsp;&nbsp; <span style="font-size:12px;">|</span> &nbsp;&nbsp; 


<a href="http://www.yell.ge/info/" target="_blank" style="font-family:myfont_m; font-size:12px; font-weight:bold; color:#333333; background:url(img/info_banner_icon_15x15.png) left no-repeat; padding-left:19px;">ინფო&nbsp;გვერდები</a> &nbsp;&nbsp; <span style="font-size:12px;">|</span> &nbsp;
<a href="http://yell.ge/privacy_policy_eng.php" style="font-family:myfont_m; font-size:12px; font-weight:bold; color:#333333;"></a>  
<a href="https://www.facebook.com/yell.ge" target="_blank" style="background:url(img/face_foot.png) center no-repeat; padding:0px 8px 0px 8px; font-size:12px;"></a>


</div>


<div style="font-family:Sylfaen; font-size:10px; padding:2px 0px 2px 0px;"></div>
<div class="row" style="max-width: 680px;">
<div style="font-family:Sylfaen; font-size:10px; margin-left: 12px; margin-bottom: 5px; padding:2px 0px 2px 0px;"><span style="font-family:Arial; font-size:10px;">© 1999 - 2023; ბიზნეს საინფორმაციო ცნობარი yell.ge (იელ.ჯი), <br> yellowpages.ge, yell.ge, YellowPages</span> საქართველოში არის შპს "ყვითელი ფურცლები თბილისის" საკუთრება</div>
</div>



    </div>

        </div>
    </div>
</div>







<div style="font-family:S; font-size:14px; color:#00AA11; display:none;" id="review_add_wait_check">თქვენი რევიუ მიღებულია და გამოქვეყნდება მოდერაციის შემდეგ. გაითვალისწინეთ, რომ ღამის საათებში და არასამუშაო დღეებში რევიუები არ ქვეყნდება.</div>


<div style="font-family:S; font-size:14px; color:#00AA11; display:none;" id="delete_review_or_not">ნამდვილად გსურთ რევიუს წაშლა?</div>
<div style="font-family:S; font-size:14px; color:#00AA11; display:none;" id="message_sent_text">შეტყობინება გაიგზავნა წარმატებით.<br>გმადლობთ, რომ სარგებლობთ ჩვენი მომსახურებით.</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="message_notsent_text">შეტყობინება არ გაიგზავნა. სცადეთ მოგვიანებით.</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="message_fillall_text">გთხოვთ, შეავსეთ ყველა ველი.</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="login_wrong_user_or_pass">ელ–ფოსტა ან პაროლი არასწორია.</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="registration_complete_go_to_activate">რეგისტრაციის დასრულებისთვის გთხოვთ შეამოწმოთ თქვენი ელ–ფოსტა: <span style="font-family:Arial; font-size:14px; color:#005E9D;"></span> (მათ შორის სპამის საქაღალდეც), რომელზეც გამოგეგზავნათ ბმული აქტივაციისთვის. ვებ–გვერდზე, თქვენს ანგარიშში შესვლას შეძლებთ აქტივაციის შემდეგ.</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="wrong_activation_code">აქტივაციის კოდი არასწორია ან თქვენს მეილზე გამოგზავნილ ბმულს გაუვიდა აქტივაციის ვადა. გთხოვთ თავიდან გაიაროთ რეგისტრაცია.</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="wrong_activation_expire">აქტივაციის კოდი არასწორია ან თქვენს მეილზე გამოგზავნილ ბმულს გაუვიდა აქტივაციის ვადა. გთხოვთ თავიდან გაიაროთ რეგისტრაცია.</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="wrong_activation_already">თქვენი ანგარიში უკვე გააქტიურებულია. შეგიძლიათ შეხვიდეთ სისტემაში.</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="activation_active">აქტივაცია წარმატებით დასრულდა.</div>

<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="reset_password_mail_not_correct">1</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="reset_password_mail_send">2</div>
<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="reset_password_mail_notsend">3</div>

<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="to_continue_please_login">გთხოვთ შეხვიდეთ სისტემაში.</div>


<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="choose_book_category_to_add">გთხოვთ აირჩიოთ კატეგორია.</div>

<div style="font-family:S; font-size:14px; color:#AA0011; display:none;" id="alert_login_to_add_company">იმისათვის, რომ შეძლოთ კომპანიის დამატება საჭიროა გაიაროთ ავტორიზაცია.</div>


<div style="width:100%; height:100%; position:fixed; left:0px; top:0px; z-index:10000; display:none;" id="alert">
<div style="width:100%; height:100%; background-color:#000000; position:fixed; left:0px; top:0px; opacity:0.5; filter:alpha(opacity=50); z-index:10001; " id="alert_bg"></div>
<table width="100%" height="100%" border="0" cellspacing="0" cellpadding="0" style="width:100%; height:100%; background-color:transparent; position:fixed; left:0px; top:0px; z-index:10002; ">
<tbody><tr>
<td align="center" valign="middle" width="100%" height="100%" style="width:100%; height:100%;">



<table border="0" cellpadding="0" cellspacing="10" bgcolor="#F9F9F9" style="border:6px solid #ffed00; box-shadow:0px 2px 7px rgba(0,0,0,0.5); border-radius:6px;" id="alert_box">
<tbody><tr>
<td width="330" align="left" valign="top"><table border="0" cellspacing="0" cellpadding="0">
<tbody><tr>
<td width="300" height="30" align="left" valign="top"><!--<img src="img/logo_2.gif" width="77" height="29" />--></td>
<td width="30" height="30" align="right" valign="top"><img src="img/close_2.png" width="12" height="12" alt="" style="margin: 5px 5px 0px 0px; cursor:pointer;" onmouseover="this.src='img/close_1.png';" onmouseout="this.src='img/close_2.png';" onclick="F_alert_close();"></td>
</tr>
</tbody></table></td>
</tr>
<tr>
<td width="330" align="left" valign="middle"><table border="0" cellspacing="0" cellpadding="0">
<tbody><tr>
<td width="34" height="34" align="left" valign="top" id="alert_icon">&nbsp;</td>
<td width="296" height="34" align="left" valign="middle" id="alert_text" style="font-family:Sylfaen; font-size:13px; font-weight:normal; color:#000000; padding-left:10px;">&nbsp;</td>
</tr>
</tbody></table></td>
</tr>
<tr>
<td width="330" height="30" align="right" valign="top">



<table width="330" height="30" border="0" cellspacing="0" cellpadding="0">
<tbody><tr>
<td width="247" height="30" align="right" id="alert_cancel">&nbsp;</td>
<td width="83" height="30" align="right" id="alert_ok">
    <div align="center" style="width:80px; height:30px; line-height:30px; font-family:Arial; font-size:14px; font-weight:normal; color:#005e9d; cursor:pointer; background:transparent url(img/alert_button_1.gif) left no-repeat;" onclick="F_alert_close();" onmouseover="this.style.background='transparent url(img/alert_button_2.gif) left no-repeat';" onmouseout="this.style.background='transparent url(img/alert_button_1.gif) left no-repeat';">OK</div></td>
</tr>
</tbody></table>



</td>
</tr>
</tbody></table>



</td>
</tr>
</tbody></table>
</div>



<div style="width:0px; height:0px; position:absolute; left:0px; top:0px;" id="PP_inner"></div>

<script type="text/javascript" language="javascript">
PG_language="geo";

only_bussiness_name=0;
show_on_map=0;
SI1_search_by=1;

lat_1=0;
lon_1=0;
lat_2=0;
lon_2=0;
lat_3=0;
lon_3=0;

location_koef=0;

SI_3_lat=0;
SI_3_lon=0;
</script>

<script type="text/javascript" language="javascript">
error_2[0]='&#4321;&#4304;&#4331;&#4312;&#4308;&#4305;&#4317; &#4321;&#4312;&#4322;&#4327;&#4309;&#4304; &#4323;&#4316;&#4307;&#4304; &#4328;&#4308;&#4307;&#4306;&#4308;&#4305;&#4317;&#4307;&#4308;&#4321; &#4315;&#4312;&#4316;&#4312;&#4315;&#4323;&#4315; &#4317;&#4320;&#4312; &#4321;&#4312;&#4315;&#4305;&#4317;&#4314;&#4317;&#4321;&#4306;&#4304;&#4316;.';error_2[1]='&#4322;&#4308;&#4314;&#4308;&#4324;&#4317;&#4316;&#4312;&#4321; &#4316;&#4317;&#4315;&#4308;&#4320;&#4312; &#4323;&#4316;&#4307;&#4304; &#4328;&#4308;&#4307;&#4306;&#4308;&#4305;&#4317;&#4307;&#4308;&#4321; &#4315;&#4312;&#4316;&#4312;&#4315;&#4323;&#4315; &#4317;&#4311;&#4334;&#4312; &#4330;&#4312;&#4324;&#4320;&#4312;&#4321;&#4306;&#4304;&#4316;.';

DD_height[0]=258;
DD_height[1]=68;

SI_object[0]=document.getElementById("SI_0");

SI_def_value_all[0]="კომპანიის სახელი ან საქმიანობა";
SI_def_value_all[1]="კომპანიის სახელი";
SI_def_value_all[2]="ტელეფონის ნომერი (მინიმუმ 4 ციფრი)";

SI_def_value[0]="კომპანიის სახელი ან საქმიანობა";
if(SI_object[0]){SI_value[0]=SI_object[0].value;}else{SI_value[0]="";}

SI_object[1]=document.getElementById("SI_1");
SI_def_value[1]="თბილისი";
if(SI_object[1]){SI_value[1]=SI_object[1].value;}else{SI_value[1]="";}


SI_object[2]=document.getElementById("SI_2");
SI_def_value[2]="მისამართი";
if(SI_object[2]){SI_value[2]=SI_object[2].value;}else{SI_value[2]="";}


SI_object[3]=document.getElementById("SI_3");
SI_def_value[3]="აირჩიეთ მდებარეობა...";
if(SI_object[3]){SI_value[3]=SI_object[3].value;}else{SI_value[3]="";}

SI_def_value["3_1"]="აირჩიეთ მდებარეობა...";

</script>

<script type="text/javascript" language="JavaScript">
GeoKBD.map('FORM_0','SI_0','current_search');
GeoKBD.map('FORM_1','SI_1','current_search');
GeoKBD.map('FORM_2','SI_2','current_search');
GeoKBD.map('FORM_3','SI_3','current_search');
</script>
<script type="text/javascript" language="JavaScript">
function F_show_all_markers()
{
//markers=[MK[153125],MK[146031],MK[140044],MK[132666],MK[108205],MK[67797],MK[76824],MK[131476],MK[107837],MK[120764],MK[75910],MK[67133],MK[79040],MK[78210],MK[145831],MK[67446],MK[80278],MK[108923]];
//new_boundary=new google.maps.LatLngBounds();
//for(index in markers){position=markers[index].position;new_boundary.extend(position);}
//map.fitBounds(new_boundary);
}


function F_set_markers()
{
}

CENTER_LAT=41.714401707574;
CENTER_LON=44.776940237028;
</script>



</body>'''

# %%
# import requests
from bs4 import BeautifulSoup
import requests
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from datetime import datetime
current_time = datetime.now().time()
import pandas as pd
# res = requests.get('https://www.yell.ge/companies.php?lan=geo&rub=445')

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
emails = ['gurami151097@gmail.com']
for i in range(5):
    # Set up Chrome options
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Run Chrome in headless mode

    # Set path to chromedriver.exe based on your configuration
    webdriver_path = '/Users/guramiivanidze/Desktop/projects/webscrap/tourcomp/chromedriver_mac_arm64/chromedriver'

    # Create a new instance of the Chrome driver
    driver = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options)



    # Load a web page
    url = f'https://www.yell.ge/companies.php?lan=geo&rub=445&SI_1=%E1%83%97%E1%83%91%E1%83%98%E1%83%9A%E1%83%98%E1%83%A1%E1%83%98&SR_pg={i}'
    driver.get(url)
    # Wait for the page to fully render
    driver.implicitly_wait(5)  
    # Get the rendered HTML
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    el = soup.find_all(id='SR_links_none')
    href_list=[]
    for div in soup.find_all('div', {'id': 'SR_links_none'}):
        a_tag = div.find('a')
        if a_tag and 'href' in a_tag.attrs:
            href_value = a_tag['href']
            href_list.append(href_value)

    
    for i in href_list:
        if i[0:7] == "mailto:":
            emails.append(i[7:])
    print(f'iter {1} ended')
# Out:
# /var/folders/zq/s5_mz9yx2q74zbff7ythfsv40000gn/T/ipykernel_22410/2201425469.py:25: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=webdriver_path, options=chrome_options)
# iter 1 ended
# iter 1 ended
# iter 1 ended
# iter 1 ended
# iter 1 ended

# %%
def send_email(param,receiver):
    if param == 'ok':
        # Email configuration
        sender_email = "gurami.ivanidze.96@gmail.com"
        receiver_email = receiver
        subject = "ყველაზე დაბალი ფასები და ვიზიარის კომპანიაში"
        message = ''' 
        გამარჯობა
        <p>მაქვს პროგრამა რომელსაც აქვს შემდეგი ფუნქციონალი:
        ვიზიარის საიტიდან იღებს არსებულ რეისებს, მოცემული რეისების ფასებიდან არჩევს 
        ყველაზე დაბალ ფასს, როგორც გამგზავრების ისე დაბრუნების.
        ყველაზე დაბარფასიანი რეoსებიდან ადგენს გაფრენა დაბრუების საუკეთესო წყვილს 
        იმის მიხედვით თუ რა ინტერვალში ეძებთ.
        პროგრამა მუშობს ნებისმიერ მიმართულებაზე, რომელიც არის ვიზიარის საიტზე </p> 
        
        <p>მეორე ფუნქციონალი არის სასურველი ფასის მიხედვით შერჩევა რეისების </p>
        
        <hr>
        <hr>
        
        <h4>მოცემული პროგრამის მუშაობის პრინციპი:</h4>
        პროგრამა იღებს შემდეგ პარამეტრებს რომლის საშუალებითაც აგენერირებს ხელსაყრელ ფრენებს
        <ul>
            <li>FROM = 'KUT' -- ფრენის მიმართულება საიდან</li>
            <li>TO = 'AUH' -- ფრენის მიმართულება სად</li>
            <li>INTERVAL = 7 -- ინტერვალი (გაფრენის თარიღსა და დაბრუნების თარიღს შორის)</li>
            <li>USER_PRICE = 123 -- მისაღები ფასი</li>
        </ul>
        <h4>შედეგი ბრუნდება შემდეგი ფორმებით ექსელის ფაილში</h4>
        <h4>პირველი შედეგი რომელიც დაგენერირდება უზერის მიერ მიწოდებული ფასით</h4>
        <p>
        <h5>1 შემთხვევა: თუ შეყვანილი თარიღი არარის ვიზიარის ფასებში ანუ ვიზაარს არაქვს ამ ფასდ ფრენა ბრუნდება შემდეგი შედეგი:</h5>
        your prices is not in Wizzair prices 
        you can choose prices from list:  [99.0, 119.0, 129.0, 139.0, 159.0, 169.0, 
        189.0, 199.0, 229.0, 259.0, 289.0, 319.0, 349.0, 379.0, 419.0, 459.0,
        509.0, 549.0, 609.0, 669.0, 739.0,]</p>

        <h5>2 შემთხვეა: თუ შეყვანილი თარიღი არის ვიზიარის ფასებში</h5>
        Dates for the price requested by the user successfully loaded
        best dates for travel generated successfuly
        <table style="border-collapse: collapse; width: 100%;">
          <thead style="background-color: lightgray;">
            <tr>
              <th style="border: 1px solid black; padding: 8px; text-align: center;">გაფრენა</th>
              <th style="border: 1px solid black; padding: 8px; text-align: center;">გაფრენის ფასი</th>
              <th style="border: 1px solid black; padding: 8px; text-align: center;">დაბრუნება</th>
              <th style="border: 1px solid black; padding: 8px; text-align: center;">დაბრუნების ფასი</th>
              <th style="border: 1px solid black; padding: 8px; text-align: center;">STATUS</th>
            </tr>
          </thead>
          <tbody>
            <tr>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">2023-10-14</td>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">139.0</td>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">2023-10-17</td>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">139.0</td>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">ACTIVE</td>
            </tr>
            <tr>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">2024-01-20</td>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">139.0</td>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">2024-01-23</td>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">139.0</td>
              <td style="border: 1px solid black; padding: 8px; text-align: center;">ACTIVE</td>
            </tr>
          </tbody>
        </table>
        <h4>მეორე შედეგი ყველაზე დაბალ ფასიანი ფრენები</h4>
        
        <table style="border-collapse: collapse; width: 100%;">
        <thead style="background-color: lightgray;">
          <tr>
            <th style="border: 1px solid black; padding: 8px; text-align: center;">გაფრენა</th>
            <th style="border: 1px solid black; padding: 8px; text-align: center;">გაფრენის ფასი</th>
            <th style="border: 1px solid black; padding: 8px; text-align: center;">დაბრუნება</th>
            <th style="border: 1px solid black; padding: 8px; text-align: center;">დაბრუნების ფასი</th>
            <th style="border: 1px solid black; padding: 8px; text-align: center;">STATUS</th>
          </tr>
        </thead>
        <tbody>
          <tr>

            <td style="border: 1px solid black; padding: 8px; text-align: center;">2023-09-04</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">99.0</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">2023-09-05</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">99.0</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">ACTIVE</td>
          </tr>
          <tr>

            <td style="border: 1px solid black; padding: 8px; text-align: center;">2023-09-05</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">99.0</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">2023-09-06</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">99.0</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">ACTIVE</td>
          </tr>
          <tr>

            <td style="border: 1px solid black; padding: 8px; text-align: center;">2023-09-06</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">99.0</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">2023-09-07</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">99.0</td>
            <td style="border: 1px solid black; padding: 8px; text-align: center;">ACTIVE</td>
          </tr>
        </tbody>
      </table>


        <h2>მოცემული პროგრამით შეგიძლიათ დაზოგოთ მოძიების დრო საუკეთესო ფასის მქონე მგზავრობის <h2>
        
        <h2> დაინტერესების შემთხვევაში გთხოვთ მომწეროთ ამავე მეილზე <h2>
        
        '''
        app_pass = 'mfilnqtlctuwaipi'
        # Create the email
        email = MIMEMultipart('related')
        
        email["From"] = sender_email
        email["To"] = receiver_email
        email["Subject"] = subject
        
        html_part = MIMEText(message, 'html')
        email.attach(html_part)

        # Connect to the SMTP server
        smtp_server = "smtp.gmail.com"
        smtp_port = 587
        smtp_connection = smtplib.SMTP(smtp_server, smtp_port)
        smtp_connection.starttls()

        # Login to your account
        smtp_connection.login(sender_email, app_pass)

        # Send the email
        smtp_connection.sendmail(
            sender_email, receiver_email, email.as_string())

        # Close the connection
        smtp_connection.quit()

# %%
for i in emails:
    send_email('ok',i)
    print(f'email succesfully send to {i}')
# Out:
# email succesfully send to gurami151097@gmail.com
# email succesfully send to wuleiskiri.andro@mail.ru
# email succesfully send to info.rbstravel@gmail.com
# email succesfully send to info@mayflower.ge
# email succesfully send to nishnianidze.1954@mail.ru
# email succesfully send to info@travelworld.ge
# email succesfully send to igs.travel.georgia@gmail.com
# email succesfully send to tamtazhvania@yahoo.com
# email succesfully send to fly.ge@hotmail.com
# email succesfully send to info@tiflistravel.ge
# email succesfully send to hostingeorgia@gmail.com
# email succesfully send to info@skytravel.ge
# email succesfully send to info@gsr.ge
# email succesfully send to info@wonderland.ge
# email succesfully send to info@maktours.ge
# email succesfully send to georgiantour@georgiantour.com.ge
# email succesfully send to info@oktravel.ge
# email succesfully send to klg2005@rambler.ru
# email succesfully send to info.sunexpress@gmail.com
# email succesfully send to viatravel@viatravel.ge
# ...
